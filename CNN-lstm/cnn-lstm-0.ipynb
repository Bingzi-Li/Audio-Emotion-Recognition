# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# Several helpful packages to load

import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/My Drive/Colab Notebooks/inputs/'

# %%
mel_spectrograms_chunked = np.load(path + 'mel_spec_data_.npy')

# %%
print(mel_spectrograms_chunked[0])
print(len(mel_spectrograms_chunked))
print(mel_spectrograms_chunked.shape)
# Out:
# [-80. -80. -80. ... -80. -80. -80.]
# 4320
# (4320, 114688)

# %%
mel_spectrograms_chunked = mel_spectrograms_chunked.reshape(4320, 7, 128, 128)

# %%
print(mel_spectrograms_chunked[0])
print(len(mel_spectrograms_chunked))
print(mel_spectrograms_chunked.shape)
# Out:
# [[[-80.         -80.         -80.         ... -57.56872947 -59.47246189
#    -58.6756208 ]
#   [-80.         -80.         -80.         ... -57.52570992 -51.7311459
#    -58.17584363]
#   [-80.         -80.         -80.         ... -54.31410735 -38.32153988
#    -51.66323489]
#   ...
#   [-80.         -80.         -80.         ... -72.8596145  -65.80870606
#    -69.61733852]
#   [-80.         -80.         -80.         ... -75.04425496 -66.22542431
#    -74.72386215]
#   [-80.         -80.         -80.         ... -75.4343771  -66.33989266
#    -74.82499545]]
#
#  [[-80.         -80.         -80.         ... -60.16898927 -46.889381
#    -49.10288993]
#   [-80.         -80.         -80.         ... -49.70241994 -44.56260986
#    -45.90952399]
#   [-80.         -80.         -80.         ... -35.93341583 -33.82007264
#    -34.32021786]
#   ...
#   [-80.         -80.         -80.         ... -73.95913366 -74.22258212
#    -80.        ]
#   [-80.         -80.         -80.         ... -80.         -74.86396546
#    -80.        ]
#   [-80.         -80.         -80.         ... -80.         -74.93539945
#    -80.        ]]
#
#  [[-63.6398013  -52.65864345 -49.09175296 ... -56.53223073 -44.93541988
#    -47.90023013]
#   [-53.18817473 -52.96913292 -49.16614827 ... -51.67687941 -44.83706424
#    -47.61939225]
#   [-39.42053271 -64.58357633 -47.58193588 ... -39.10093616 -41.03975106
#    -42.34578427]
#   ...
#   [-63.20674239 -70.04515427 -68.95771805 ... -60.41107512 -55.76948304
#    -60.98498255]
#   [-67.0665364  -79.76185803 -69.35224584 ... -66.93417704 -62.72042404
#    -68.37127456]
#   [-67.23695678 -80.         -69.463656   ... -68.91811475 -64.12881459
#    -69.3416948 ]]
#
#  ...
#
#  [[-50.45352721 -53.14388662 -53.3368141  ... -34.3878207  -34.0415687
#    -32.99632619]
#   [-49.91176179 -52.04369236 -53.64480809 ... -32.88823548 -32.49439953
#    -31.55240645]
#   [-43.20305866 -43.43639775 -64.41026967 ... -23.3933497  -22.90963646
#    -22.16638161]
#   ...
#   [-61.74274223 -68.98280572 -68.4432317  ... -80.         -80.
#    -80.        ]
#   [-64.67422155 -77.88716429 -70.4722     ... -80.         -80.
#    -80.        ]
#   [-65.1897373  -80.         -71.04298277 ... -80.         -80.
#    -80.        ]]
#
#  [[-43.04356491 -41.8013536  -40.05084965 ... -58.34158717 -57.98690971
#    -50.75285909]
#   [-40.93579077 -40.08040561 -38.65474735 ... -56.95737455 -56.5881496
#    -49.18872127]
#   [-30.46914615 -30.18995011 -29.3656253  ... -47.69285545 -47.293556
#    -39.57258553]
#   ...
#   [-80.         -80.         -80.         ... -80.         -80.
#    -80.        ]
#   [-80.         -80.         -80.         ... -80.         -80.
#    -80.        ]
#   [-80.         -80.         -80.         ... -80.         -80.
#    -80.        ]]
#
#  [[-33.72440935 -35.58126631 -36.85745655 ... -75.81229737 -73.31878695
#    -80.        ]
#   [-32.20450198 -34.34670228 -36.04174628 ... -75.40517662 -73.47709829
#    -80.        ]
#   [-22.67088295 -25.41068693 -28.26843659 ... -69.36714411 -73.64839832
#    -80.        ]
#   ...
#   [-80.         -80.         -80.         ... -80.         -80.
#    -80.        ]
#   [-80.         -80.         -80.         ... -80.         -80.
#    -80.        ]
#   [-80.         -80.         -80.         ... -80.         -80.
#    -80.        ]]]
# 4320
# (4320, 7, 128, 128)

# %% [markdown]
# ### Create model

# %%
import torch
import torch.nn as nn
# BATCH FIRST TimeDistributed layer
class TimeDistributed(nn.Module):
    def __init__(self, module):
        super(TimeDistributed, self).__init__()
        self.module = module

    def forward(self, x):

        if len(x.size()) <= 2:
            return self.module(x)
        # squash samples and timesteps into a single axis
        elif x.size() == 3: # (samples, timesteps, inp1)
            x_reshape = x.contiguous().view(-1, x.size(2))  # (samples * timesteps, inp1)
        elif x.size() == 4: # (samples,timesteps,inp1,inp2)
            x_reshape = x.contiguous().view(-1, x.size(2), x.size(3)) # (samples*timesteps,inp1,inp2)
        else: # (samples,timesteps,inp1,inp2,inp3)
            x_reshape = x.contiguous().view(-1, x.size(2), x.size(3),x.size(4)) # (samples*timesteps,inp1,inp2,inp3)
            
        y = self.module(x_reshape)
        
        # we have to reshape Y
        if x.size() == 3:
            y = y.contiguous().view(x.size(0), -1, y.size(1))  # (samples, timesteps, out1)
        elif x.size() == 4:
            y = y.contiguous().view(x.size(0), -1, y.size(1), y.size(2)) # (samples, timesteps, out1,out2)
        else:
            y = y.contiguous().view(x.size(0), -1, y.size(1), y.size(2),y.size(3)) # (samples, timesteps, out1,out2, out3)
        return y

# %%
class HybridModel(nn.Module):
    def __init__(self,num_emotions):
        super().__init__()
        # conv block
        self.conv2Dblock = nn.Sequential(
            # 1. conv block
            TimeDistributed(nn.Conv2d(in_channels=1,
                                   out_channels=16,
                                   kernel_size=3,
                                   stride=1,
                                   padding=1
                                  )),
            TimeDistributed(nn.BatchNorm2d(16)),
            TimeDistributed(nn.ReLU()),
            TimeDistributed(nn.MaxPool2d(kernel_size=2, stride=2)),
            TimeDistributed(nn.Dropout(p=0.4)),
            # 2. conv block
            TimeDistributed(nn.Conv2d(in_channels=16,
                                   out_channels=32,
                                   kernel_size=3,
                                   stride=1,
                                   padding=1
                                  )),
            TimeDistributed(nn.BatchNorm2d(32)),
            TimeDistributed(nn.ReLU()),
            TimeDistributed(nn.MaxPool2d(kernel_size=4, stride=4)),
            TimeDistributed(nn.Dropout(p=0.4)),
            # 3. conv block
            TimeDistributed(nn.Conv2d(in_channels=32,
                                   out_channels=64,
                                   kernel_size=3,
                                   stride=1,
                                   padding=1
                                  )),
            TimeDistributed(nn.BatchNorm2d(64)),
            TimeDistributed(nn.ReLU()),
            TimeDistributed(nn.MaxPool2d(kernel_size=4, stride=4)),
            TimeDistributed(nn.Dropout(p=0.4)),
            # 4. conv block
            TimeDistributed(nn.Conv2d(in_channels=64,
                                   out_channels=128,
                                   kernel_size=3,
                                   stride=1,
                                   padding=1
                                  )),
            TimeDistributed(nn.BatchNorm2d(128)),
            TimeDistributed(nn.ReLU()),
            TimeDistributed(nn.MaxPool2d(kernel_size=4, stride=4)),
            TimeDistributed(nn.Dropout(p=0.4))
        )
        # LSTM block
        hidden_size = 64
        self.lstm = nn.LSTM(input_size=128,hidden_size=hidden_size,bidirectional=False, batch_first=True) 
        self.dropout_lstm = nn.Dropout(p=0.3)
        # Linear softmax layer
        self.out_linear = nn.Linear(hidden_size,num_emotions)
    def forward(self,x):
        conv_embedding = self.conv2Dblock(x)
        conv_embedding = torch.flatten(conv_embedding, start_dim=2) # do not flatten batch dimension and time
        lstm_embedding, (h,c) = self.lstm(conv_embedding)
        lstm_embedding = self.dropout_lstm(lstm_embedding)
        # lstm_embedding (batch, time, hidden_size)
        lstm_output = lstm_embedding[:,-1,:] 
        output_logits = self.out_linear(lstm_output)
        output_softmax = nn.functional.softmax(output_logits,dim=1)
        return output_logits, output_softmax

# %%
def loss_fnc(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions,target=targets)

# %% [markdown]
# ### Training

# %%
def make_train_step(model, loss_fnc, optimizer):
    def train_step(X,Y):
        # set model to train mode
        model.train()
        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax,dim=1)
        accuracy = torch.sum(Y==predictions)/float(len(Y))
        # compute loss
        loss = loss_fnc(output_logits, Y)
        # compute gradients
        loss.backward()
        # update parameters and zero gradients
        optimizer.step()
        optimizer.zero_grad()
        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model,loss_fnc):
    def validate(X,Y):
        with torch.no_grad():
            model.eval()
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax,dim=1)
            accuracy = torch.sum(Y==predictions)/float(len(Y))
            loss = loss_fnc(output_logits,Y)
        return loss.item(), accuracy*100, predictions
    return validate

# %%
X = np.stack(mel_spectrograms_chunked,axis=0)
X = np.expand_dims(X,2)
print('Shape of data: ',X.shape)

del mel_spectrograms_chunked
# Out:
# Shape of data:  (4320, 7, 1, 128, 128)

# %%
EMOTIONS = {1:'neutral', 2:'calm', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust', 0:'surprise'} # surprise je promenjen sa 8 na 0
# DATA_PATH = './inputs/Audio_Speech_Actors_01-24/'
# data = pd.DataFrame(columns=['Emotion', 'Intensity', 'Gender','Path'])

# for dirname, _, filenames in os.walk(DATA_PATH):
#     for filename in filenames:
#         file_path = os.path.join(dirname, filename)
#         identifiers = filename.split('.')[0].split('-')
#         emotion = (int(identifiers[2]))
#         if emotion == 8: # promeni surprise sa 8 na 0
#             emotion = 0
#         if int(identifiers[3]) == 1:
#             emotion_intensity = 'normal' 
#         else:
#             emotion_intensity = 'strong'
#         if int(identifiers[6])%2 == 0:
#             gender = 'female'
#         else:
#             gender = 'male'
        
#         data = data.append({"Emotion": emotion,
#                             "Intensity": emotion_intensity,
#                             "Gender": gender,
#                             "Path": file_path
#                              },
#                              ignore_index = True
#                           )
# print("number of files is {}".format(len(data)))
# data.head()

# %%
# print(type(data))

# %%
# print(data.iloc[0])

# %%
# print(len(data))

# %%
data_df = pd.read_pickle(path + "data_df.pkl")

# %%
data_df.head()
# Out:
#   Emotion Intensity  Gender                                               Path
# 0       5    normal  female  ./inputs/Audio_Speech_Actors_01-24/Actor_16/03...
# 1       6    normal  female  ./inputs/Audio_Speech_Actors_01-24/Actor_16/03...
# 2       6    strong  female  ./inputs/Audio_Speech_Actors_01-24/Actor_16/03...
# 3       5    strong  female  ./inputs/Audio_Speech_Actors_01-24/Actor_16/03...
# 4       7    normal  female  ./inputs/Audio_Speech_Actors_01-24/Actor_16/03...

# %%
print(len(data_df))
# Out:
# 4320

# %%
# split data: (train,val,test) --> (80%,10%,10%) proportionaly for each emotion (class)
train_ind,test_ind,val_ind = [],[],[]
X_train,X_val,X_test = [],[],[]
Y_train,Y_val,Y_test = [],[],[]
for emotion in range(len(EMOTIONS)):
    emotion_ind = list(data_df.loc[data_df.Emotion==emotion,'Emotion'].index)
    emotion_ind = np.random.permutation(emotion_ind)
    m = len(emotion_ind)
    ind_train = emotion_ind[:int(0.8*m)]
    ind_val = emotion_ind[int(0.8*m):int(0.9*m)]
    ind_test = emotion_ind[int(0.9*m):]
    X_train.append(X[ind_train,:,:,:])
    Y_train.append(np.array([emotion]*len(ind_train),dtype=np.int32))
    X_val.append(X[ind_val,:,:,:])
    Y_val.append(np.array([emotion]*len(ind_val),dtype=np.int32))
    X_test.append(X[ind_test,:,:,:])
    Y_test.append(np.array([emotion]*len(ind_test),dtype=np.int32))
    train_ind.append(ind_train)
    test_ind.append(ind_test)
    val_ind.append(ind_val)
X_train = np.concatenate(X_train,0)
X_val = np.concatenate(X_val,0)
X_test = np.concatenate(X_test,0)
Y_train = np.concatenate(Y_train,0)
Y_val = np.concatenate(Y_val,0)
Y_test = np.concatenate(Y_test,0)
train_ind = np.concatenate(train_ind,0)
val_ind = np.concatenate(val_ind,0)
test_ind = np.concatenate(test_ind,0)
print(f'X_train:{X_train.shape}, Y_train:{Y_train.shape}')
print(f'X_val:{X_val.shape}, Y_val:{Y_val.shape}')
print(f'X_test:{X_test.shape}, Y_test:{Y_test.shape}')
# check if all are unique
unique, count = np.unique(np.concatenate([train_ind,test_ind,val_ind],0), return_counts=True)
print("Number of unique indexes is {}, out of {}".format(sum(count==1), X.shape[0]))

del X
# Out:
# X_train:(3450, 7, 1, 128, 128), Y_train:(3450,)
# X_val:(435, 7, 1, 128, 128), Y_val:(435,)
# X_test:(435, 7, 1, 128, 128), Y_test:(435,)
# Number of unique indexes is 4320, out of 4320

# %%
# scale data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

b,t,c,h,w = X_train.shape
X_train = np.reshape(X_train, newshape=(b,-1))
X_train = scaler.fit_transform(X_train)
X_train = np.reshape(X_train, newshape=(b,t,c,h,w))

b,t,c,h,w = X_test.shape
X_test = np.reshape(X_test, newshape=(b,-1))
X_test = scaler.transform(X_test)
X_test = np.reshape(X_test, newshape=(b,t,c,h,w))

b,t,c,h,w = X_val.shape
X_val = np.reshape(X_val, newshape=(b,-1))
X_val = scaler.transform(X_val)
X_val = np.reshape(X_val, newshape=(b,t,c,h,w))

# %%
# import torch
# device = 'cuda' if torch.cuda.is_available() else 'cpu'
# print('Selected device is {}'.format(device))
# Out:
# Selected device is cuda

# %%
# training
EPOCHS=500
DATASET_SIZE = X_train.shape[0]
BATCH_SIZE = 32
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Selected device is {}'.format(device))
model = HybridModel(num_emotions=len(EMOTIONS)).to(device)
print('Number of trainable params: ',sum(p.numel() for p in model.parameters()) )
OPTIMIZER = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

train_step = make_train_step(model, loss_fnc, optimizer=OPTIMIZER)
validate = make_validate_fnc(model,loss_fnc)
losses=[]
val_losses = []
acc_lst = []
val_acc_lst = []
for epoch in range(EPOCHS):
    # schuffle data
    ind = np.random.permutation(DATASET_SIZE)
    X_train = X_train[ind,:,:,:,:]
    Y_train = Y_train[ind]
    epoch_acc = 0
    epoch_loss = 0
    iters = int(DATASET_SIZE / BATCH_SIZE)
    for i in range(iters):
        batch_start = i * BATCH_SIZE
        batch_end = min(batch_start + BATCH_SIZE, DATASET_SIZE)
        actual_batch_size = batch_end-batch_start
        X = X_train[batch_start:batch_end,:,:,:,:]
        Y = Y_train[batch_start:batch_end]
        X_tensor = torch.tensor(X,device=device).float()
        Y_tensor = torch.tensor(Y, dtype=torch.long,device=device)
        loss, acc = train_step(X_tensor,Y_tensor)
        epoch_acc += acc*actual_batch_size/DATASET_SIZE
        epoch_loss += loss*actual_batch_size/DATASET_SIZE
        print(f"\r Epoch {epoch}: iteration {i}/{iters}",end='')
    X_val_tensor = torch.tensor(X_val,device=device).float()
    Y_val_tensor = torch.tensor(Y_val,dtype=torch.long,device=device)
    val_loss, val_acc, _ = validate(X_val_tensor,Y_val_tensor)
    acc_lst.append(acc)
    val_acc_lst.append(val_acc)
    losses.append(epoch_loss)
    val_losses.append(val_loss)
    print('')
    print(f"Epoch {epoch} --> loss:{epoch_loss:.4f}, acc:{epoch_acc:.2f}%, val_loss:{val_loss:.4f}, val_acc:{val_acc:.2f}%")
# Out:
# Selected device is cuda
# Number of trainable params:  147816
#  Epoch 0: iteration 106/107
# Epoch 0 --> loss:2.0450, acc:15.77%, val_loss:2.0876, val_acc:13.33%
#  Epoch 1: iteration 106/107
# Epoch 1 --> loss:2.0021, acc:18.06%, val_loss:2.1193, val_acc:14.94%
#  Epoch 2: iteration 106/107
# Epoch 2 --> loss:1.9752, acc:19.48%, val_loss:2.1592, val_acc:13.79%
#  Epoch 3: iteration 106/107
# Epoch 3 --> loss:1.9618, acc:20.87%, val_loss:2.1835, val_acc:13.56%
#  Epoch 4: iteration 106/107
# Epoch 4 --> loss:1.9482, acc:20.93%, val_loss:2.1947, val_acc:13.79%
#  Epoch 5: iteration 106/107
# Epoch 5 --> loss:1.9388, acc:22.99%, val_loss:2.1669, val_acc:13.10%
#  Epoch 6: iteration 106/107
# Epoch 6 --> loss:1.9180, acc:24.03%, val_loss:2.1154, val_acc:14.94%
#  Epoch 7: iteration 106/107
# Epoch 7 --> loss:1.8838, acc:24.90%, val_loss:2.0686, val_acc:18.16%
#  Epoch 8: iteration 106/107
# Epoch 8 --> loss:1.8348, acc:28.90%, val_loss:1.9533, val_acc:24.83%
#  Epoch 9: iteration 106/107
# Epoch 9 --> loss:1.7881, acc:30.00%, val_loss:1.8923, val_acc:29.20%
#  Epoch 10: iteration 106/107
# Epoch 10 --> loss:1.7664, acc:30.67%, val_loss:1.8314, val_acc:30.11%
#  Epoch 11: iteration 106/107
# Epoch 11 --> loss:1.7456, acc:31.25%, val_loss:1.8548, val_acc:30.11%
#  Epoch 12: iteration 106/107
# Epoch 12 --> loss:1.7150, acc:33.22%, val_loss:1.8060, val_acc:30.57%
#  Epoch 13: iteration 106/107
# Epoch 13 --> loss:1.6980, acc:33.28%, val_loss:1.8011, val_acc:29.43%
#  Epoch 14: iteration 106/107
# Epoch 14 --> loss:1.6865, acc:33.39%, val_loss:1.7606, val_acc:30.80%
#  Epoch 15: iteration 106/107
# Epoch 15 --> loss:1.6793, acc:33.62%, val_loss:1.8015, val_acc:27.13%
#  Epoch 16: iteration 106/107
# Epoch 16 --> loss:1.6641, acc:33.86%, val_loss:1.7392, val_acc:32.18%
#  Epoch 17: iteration 106/107
# Epoch 17 --> loss:1.6359, acc:35.71%, val_loss:1.7279, val_acc:32.41%
#  Epoch 18: iteration 106/107
# Epoch 18 --> loss:1.6389, acc:34.61%, val_loss:1.6783, val_acc:32.18%
#  Epoch 19: iteration 106/107
# Epoch 19 --> loss:1.6159, acc:36.78%, val_loss:1.6649, val_acc:34.25%
#  Epoch 20: iteration 106/107
# Epoch 20 --> loss:1.5978, acc:36.38%, val_loss:1.6276, val_acc:32.41%
#  Epoch 21: iteration 106/107
# Epoch 21 --> loss:1.5888, acc:38.23%, val_loss:1.6488, val_acc:35.86%
#  Epoch 22: iteration 106/107
# Epoch 22 --> loss:1.5680, acc:38.61%, val_loss:1.6038, val_acc:38.62%
#  Epoch 23: iteration 106/107
# Epoch 23 --> loss:1.5813, acc:38.49%, val_loss:1.6146, val_acc:36.55%
#  Epoch 24: iteration 106/107
# Epoch 24 --> loss:1.5626, acc:38.93%, val_loss:1.6109, val_acc:33.79%
#  Epoch 25: iteration 106/107
# Epoch 25 --> loss:1.5379, acc:38.61%, val_loss:1.5908, val_acc:36.55%
#  Epoch 26: iteration 106/107
# Epoch 26 --> loss:1.5249, acc:40.17%, val_loss:1.5407, val_acc:39.54%
#  Epoch 27: iteration 106/107
# Epoch 27 --> loss:1.5129, acc:40.70%, val_loss:1.5932, val_acc:35.63%
#  Epoch 28: iteration 106/107
# Epoch 28 --> loss:1.5099, acc:40.06%, val_loss:1.4580, val_acc:42.07%
#  Epoch 29: iteration 106/107
# Epoch 29 --> loss:1.4916, acc:42.06%, val_loss:1.4664, val_acc:40.46%
#  Epoch 30: iteration 106/107
# Epoch 30 --> loss:1.4947, acc:41.30%, val_loss:1.5325, val_acc:37.24%
#  Epoch 31: iteration 106/107
# Epoch 31 --> loss:1.4830, acc:40.99%, val_loss:1.4661, val_acc:44.37%
#  Epoch 32: iteration 106/107
# Epoch 32 --> loss:1.4540, acc:43.28%, val_loss:1.4599, val_acc:40.00%
#  Epoch 33: iteration 106/107
# Epoch 33 --> loss:1.4546, acc:44.00%, val_loss:1.4941, val_acc:40.00%
#  Epoch 34: iteration 106/107
# Epoch 34 --> loss:1.4387, acc:44.67%, val_loss:1.4308, val_acc:44.37%
#  Epoch 35: iteration 106/107
# Epoch 35 --> loss:1.4095, acc:45.30%, val_loss:1.3984, val_acc:46.44%
#  Epoch 36: iteration 106/107
# Epoch 36 --> loss:1.4239, acc:45.01%, val_loss:1.3725, val_acc:45.29%
#  Epoch 37: iteration 106/107
# Epoch 37 --> loss:1.3937, acc:46.06%, val_loss:1.3485, val_acc:47.36%
#  Epoch 38: iteration 106/107
# Epoch 38 --> loss:1.3847, acc:46.55%, val_loss:1.2832, val_acc:46.90%
#  Epoch 39: iteration 106/107
# Epoch 39 --> loss:1.3737, acc:46.49%, val_loss:1.4336, val_acc:44.60%
#  Epoch 40: iteration 106/107
# Epoch 40 --> loss:1.3581, acc:47.83%, val_loss:1.2733, val_acc:52.87%
#  Epoch 41: iteration 106/107
# Epoch 41 --> loss:1.3246, acc:48.52%, val_loss:1.2130, val_acc:53.79%
#  Epoch 42: iteration 106/107
# Epoch 42 --> loss:1.3258, acc:49.07%, val_loss:1.3857, val_acc:47.13%
#  Epoch 43: iteration 106/107
# Epoch 43 --> loss:1.3141, acc:49.59%, val_loss:1.4590, val_acc:40.00%
#  Epoch 44: iteration 106/107
# Epoch 44 --> loss:1.3206, acc:48.84%, val_loss:1.1898, val_acc:52.87%
#  Epoch 45: iteration 106/107
# Epoch 45 --> loss:1.2712, acc:50.38%, val_loss:1.1548, val_acc:58.62%
#  Epoch 46: iteration 106/107
# Epoch 46 --> loss:1.2745, acc:50.09%, val_loss:1.0977, val_acc:57.24%
#  Epoch 47: iteration 106/107
# Epoch 47 --> loss:1.2459, acc:51.22%, val_loss:1.1170, val_acc:57.70%
#  Epoch 48: iteration 106/107
# Epoch 48 --> loss:1.2607, acc:51.28%, val_loss:1.1573, val_acc:55.40%
#  Epoch 49: iteration 106/107
# Epoch 49 --> loss:1.2545, acc:51.36%, val_loss:1.1320, val_acc:55.86%
#  Epoch 50: iteration 106/107
# Epoch 50 --> loss:1.2226, acc:52.49%, val_loss:1.1311, val_acc:57.01%
#  Epoch 51: iteration 106/107
# Epoch 51 --> loss:1.2020, acc:53.07%, val_loss:1.0675, val_acc:61.15%
#  Epoch 52: iteration 106/107
# Epoch 52 --> loss:1.2034, acc:52.72%, val_loss:1.5180, val_acc:40.23%
#  Epoch 53: iteration 106/107
# Epoch 53 --> loss:1.1958, acc:53.97%, val_loss:1.1934, val_acc:56.55%
#  Epoch 54: iteration 106/107
# Epoch 54 --> loss:1.1747, acc:55.51%, val_loss:1.3108, val_acc:47.13%
#  Epoch 55: iteration 106/107
# Epoch 55 --> loss:1.1562, acc:55.83%, val_loss:1.1263, val_acc:55.17%
#  Epoch 56: iteration 106/107
# Epoch 56 --> loss:1.1431, acc:56.43%, val_loss:1.1763, val_acc:50.80%
#  Epoch 57: iteration 106/107
# Epoch 57 --> loss:1.1240, acc:56.87%, val_loss:1.0506, val_acc:61.61%
#  Epoch 58: iteration 106/107
# Epoch 58 --> loss:1.1391, acc:55.51%, val_loss:1.2403, val_acc:52.64%
#  Epoch 59: iteration 106/107
# Epoch 59 --> loss:1.1150, acc:57.16%, val_loss:1.2151, val_acc:51.95%
#  Epoch 60: iteration 106/107
# Epoch 60 --> loss:1.1234, acc:56.14%, val_loss:1.0176, val_acc:60.92%
#  Epoch 61: iteration 106/107
# Epoch 61 --> loss:1.0872, acc:57.16%, val_loss:1.1448, val_acc:54.71%
#  Epoch 62: iteration 106/107
# Epoch 62 --> loss:1.0914, acc:56.99%, val_loss:0.9757, val_acc:61.84%
#  Epoch 63: iteration 106/107
# Epoch 63 --> loss:1.0674, acc:58.43%, val_loss:0.9206, val_acc:66.44%
#  Epoch 64: iteration 106/107
# Epoch 64 --> loss:1.0576, acc:59.91%, val_loss:1.0640, val_acc:60.23%
#  Epoch 65: iteration 106/107
# Epoch 65 --> loss:1.0492, acc:59.28%, val_loss:0.9534, val_acc:64.83%
#  Epoch 66: iteration 106/107
# Epoch 66 --> loss:1.0375, acc:60.32%, val_loss:0.9482, val_acc:65.52%
#  Epoch 67: iteration 106/107
# Epoch 67 --> loss:1.0096, acc:61.68%, val_loss:0.9478, val_acc:65.29%
#  Epoch 68: iteration 106/107
# Epoch 68 --> loss:1.0212, acc:60.20%, val_loss:0.9860, val_acc:63.22%
#  Epoch 69: iteration 106/107
# Epoch 69 --> loss:0.9963, acc:62.41%, val_loss:1.0525, val_acc:59.77%
#  Epoch 70: iteration 106/107
# Epoch 70 --> loss:0.9974, acc:61.33%, val_loss:0.8904, val_acc:67.59%
#  Epoch 71: iteration 106/107
# Epoch 71 --> loss:0.9937, acc:61.39%, val_loss:0.9481, val_acc:61.84%
#  Epoch 72: iteration 106/107
# Epoch 72 --> loss:0.9786, acc:62.49%, val_loss:1.2848, val_acc:50.57%
#  Epoch 73: iteration 106/107
# Epoch 73 --> loss:0.9645, acc:63.45%, val_loss:0.9595, val_acc:64.37%
#  Epoch 74: iteration 106/107
# Epoch 74 --> loss:0.9601, acc:62.93%, val_loss:0.9208, val_acc:63.91%
#  Epoch 75: iteration 106/107
# Epoch 75 --> loss:0.9419, acc:63.10%, val_loss:0.9891, val_acc:63.68%
#  Epoch 76: iteration 106/107
# Epoch 76 --> loss:0.9295, acc:65.04%, val_loss:0.8716, val_acc:68.05%
#  Epoch 77: iteration 106/107
# Epoch 77 --> loss:0.9208, acc:64.72%, val_loss:0.8923, val_acc:65.75%
#  Epoch 78: iteration 106/107
# Epoch 78 --> loss:0.9138, acc:66.09%, val_loss:0.8071, val_acc:70.80%
#  Epoch 79: iteration 106/107
# Epoch 79 --> loss:0.8831, acc:65.80%, val_loss:0.8504, val_acc:67.59%
#  Epoch 80: iteration 106/107
# Epoch 80 --> loss:0.8745, acc:66.72%, val_loss:1.1225, val_acc:57.01%
#  Epoch 81: iteration 106/107
# Epoch 81 --> loss:0.8520, acc:68.00%, val_loss:0.9250, val_acc:67.36%
#  Epoch 82: iteration 106/107
# Epoch 82 --> loss:0.8657, acc:68.09%, val_loss:0.8529, val_acc:69.20%
#  Epoch 83: iteration 106/107
# Epoch 83 --> loss:0.8522, acc:67.97%, val_loss:0.9701, val_acc:63.91%
#  Epoch 84: iteration 106/107
# Epoch 84 --> loss:0.8192, acc:69.28%, val_loss:0.7661, val_acc:71.26%
#  Epoch 85: iteration 106/107
# Epoch 85 --> loss:0.8180, acc:68.46%, val_loss:0.9754, val_acc:62.30%
#  Epoch 86: iteration 106/107
# Epoch 86 --> loss:0.7987, acc:69.04%, val_loss:0.7818, val_acc:71.95%
#  Epoch 87: iteration 106/107
# Epoch 87 --> loss:0.7923, acc:70.99%, val_loss:0.9305, val_acc:66.21%
#  Epoch 88: iteration 106/107
# Epoch 88 --> loss:0.7846, acc:70.84%, val_loss:1.0149, val_acc:59.77%
#  Epoch 89: iteration 106/107
# Epoch 89 --> loss:0.7946, acc:70.81%, val_loss:0.9716, val_acc:62.53%
#  Epoch 90: iteration 106/107
# Epoch 90 --> loss:0.7589, acc:71.65%, val_loss:0.9060, val_acc:62.99%
#  Epoch 91: iteration 106/107
# Epoch 91 --> loss:0.7787, acc:70.32%, val_loss:0.9634, val_acc:62.53%
#  Epoch 92: iteration 106/107
# Epoch 92 --> loss:0.7397, acc:72.09%, val_loss:0.8733, val_acc:68.74%
#  Epoch 93: iteration 106/107
# Epoch 93 --> loss:0.7525, acc:71.48%, val_loss:0.8633, val_acc:69.66%
#  Epoch 94: iteration 106/107
# Epoch 94 --> loss:0.7262, acc:72.26%, val_loss:0.7745, val_acc:72.18%
#  Epoch 95: iteration 106/107
# Epoch 95 --> loss:0.7377, acc:72.78%, val_loss:0.7796, val_acc:68.74%
#  Epoch 96: iteration 106/107
# Epoch 96 --> loss:0.7425, acc:71.62%, val_loss:0.9821, val_acc:60.46%
#  Epoch 97: iteration 106/107
# Epoch 97 --> loss:0.7223, acc:73.07%, val_loss:0.9260, val_acc:65.06%
#  Epoch 98: iteration 106/107
# Epoch 98 --> loss:0.6952, acc:73.59%, val_loss:0.8931, val_acc:64.83%
#  Epoch 99: iteration 106/107
# Epoch 99 --> loss:0.6980, acc:73.86%, val_loss:0.9491, val_acc:62.30%
#  Epoch 100: iteration 106/107
# Epoch 100 --> loss:0.7022, acc:73.01%, val_loss:0.7585, val_acc:71.72%
#  Epoch 101: iteration 106/107
# Epoch 101 --> loss:0.6598, acc:75.36%, val_loss:0.9000, val_acc:62.99%
#  Epoch 102: iteration 106/107
# Epoch 102 --> loss:0.6645, acc:74.87%, val_loss:0.8939, val_acc:65.98%
#  Epoch 103: iteration 106/107
# Epoch 103 --> loss:0.6564, acc:75.91%, val_loss:0.8145, val_acc:69.20%
#  Epoch 104: iteration 106/107
# Epoch 104 --> loss:0.6549, acc:75.94%, val_loss:0.7356, val_acc:72.87%
#  Epoch 105: iteration 106/107
# Epoch 105 --> loss:0.6580, acc:74.72%, val_loss:0.6666, val_acc:78.62%
#  Epoch 106: iteration 106/107
# Epoch 106 --> loss:0.6366, acc:75.80%, val_loss:0.6614, val_acc:79.54%
#  Epoch 107: iteration 106/107
# Epoch 107 --> loss:0.6338, acc:76.14%, val_loss:0.7763, val_acc:70.80%
#  Epoch 108: iteration 106/107
# Epoch 108 --> loss:0.6146, acc:76.17%, val_loss:0.7153, val_acc:72.41%
#  Epoch 109: iteration 106/107
# Epoch 109 --> loss:0.6316, acc:76.26%, val_loss:0.8213, val_acc:67.36%
#  Epoch 110: iteration 106/107
# Epoch 110 --> loss:0.5963, acc:77.25%, val_loss:0.8025, val_acc:69.89%
#  Epoch 111: iteration 106/107
# Epoch 111 --> loss:0.6278, acc:76.20%, val_loss:0.8880, val_acc:66.21%
#  Epoch 112: iteration 106/107
# Epoch 112 --> loss:0.6253, acc:75.80%, val_loss:0.8063, val_acc:66.44%
#  Epoch 113: iteration 106/107
# Epoch 113 --> loss:0.6032, acc:77.51%, val_loss:0.9157, val_acc:63.68%
#  Epoch 114: iteration 106/107
# Epoch 114 --> loss:0.5906, acc:77.77%, val_loss:0.6879, val_acc:73.33%
#  Epoch 115: iteration 106/107
# Epoch 115 --> loss:0.5972, acc:77.80%, val_loss:0.8059, val_acc:70.11%
#  Epoch 116: iteration 106/107
# Epoch 116 --> loss:0.5863, acc:77.42%, val_loss:0.6664, val_acc:75.40%
#  Epoch 117: iteration 106/107
# Epoch 117 --> loss:0.5632, acc:78.49%, val_loss:0.7585, val_acc:71.03%
#  Epoch 118: iteration 106/107
# Epoch 118 --> loss:0.5682, acc:79.10%, val_loss:0.6206, val_acc:80.00%
#  Epoch 119: iteration 106/107
# Epoch 119 --> loss:0.5694, acc:79.22%, val_loss:0.7786, val_acc:71.03%
#  Epoch 120: iteration 106/107
# Epoch 120 --> loss:0.5916, acc:77.07%, val_loss:0.9512, val_acc:61.84%
#  Epoch 121: iteration 106/107
# Epoch 121 --> loss:0.5654, acc:78.96%, val_loss:0.6778, val_acc:77.47%
#  Epoch 122: iteration 106/107
# Epoch 122 --> loss:0.5739, acc:78.67%, val_loss:1.2238, val_acc:55.86%
#  Epoch 123: iteration 106/107
# Epoch 123 --> loss:0.5823, acc:78.29%, val_loss:0.6518, val_acc:76.55%
#  Epoch 124: iteration 106/107
# Epoch 124 --> loss:0.5452, acc:79.54%, val_loss:0.8124, val_acc:68.97%
#  Epoch 125: iteration 106/107
# Epoch 125 --> loss:0.5668, acc:78.49%, val_loss:0.7081, val_acc:75.63%
#  Epoch 126: iteration 106/107
# Epoch 126 --> loss:0.5506, acc:79.65%, val_loss:0.5409, val_acc:80.46%
#  Epoch 127: iteration 106/107
# Epoch 127 --> loss:0.5057, acc:80.32%, val_loss:0.7670, val_acc:70.80%
#  Epoch 128: iteration 106/107
# Epoch 128 --> loss:0.5469, acc:80.06%, val_loss:0.6305, val_acc:76.78%
#  Epoch 129: iteration 106/107
# Epoch 129 --> loss:0.5499, acc:79.59%, val_loss:0.6885, val_acc:73.79%
#  Epoch 130: iteration 106/107
# Epoch 130 --> loss:0.5068, acc:80.70%, val_loss:0.7385, val_acc:75.40%
#  Epoch 131: iteration 106/107
# Epoch 131 --> loss:0.5378, acc:80.17%, val_loss:0.5732, val_acc:80.69%
#  Epoch 132: iteration 106/107
# Epoch 132 --> loss:0.5257, acc:80.81%, val_loss:0.6370, val_acc:74.94%
#  Epoch 133: iteration 106/107
# Epoch 133 --> loss:0.5183, acc:80.52%, val_loss:0.7883, val_acc:69.20%
#  Epoch 134: iteration 106/107
# Epoch 134 --> loss:0.5076, acc:80.43%, val_loss:0.5190, val_acc:82.99%
#  Epoch 135: iteration 106/107
# Epoch 135 --> loss:0.4740, acc:82.38%, val_loss:1.0116, val_acc:60.46%
#  Epoch 136: iteration 106/107
# Epoch 136 --> loss:0.4773, acc:82.43%, val_loss:0.6048, val_acc:78.16%
#  Epoch 137: iteration 106/107
# Epoch 137 --> loss:0.5029, acc:80.52%, val_loss:0.7417, val_acc:68.51%
#  Epoch 138: iteration 106/107
# Epoch 138 --> loss:0.4848, acc:81.13%, val_loss:0.5418, val_acc:80.00%
#  Epoch 139: iteration 106/107
# Epoch 139 --> loss:0.5034, acc:81.10%, val_loss:0.5412, val_acc:80.46%
#  Epoch 140: iteration 106/107
# Epoch 140 --> loss:0.4776, acc:82.70%, val_loss:0.6877, val_acc:74.02%
#  Epoch 141: iteration 106/107
# Epoch 141 --> loss:0.5097, acc:81.36%, val_loss:0.6400, val_acc:77.01%
#  Epoch 142: iteration 106/107
# Epoch 142 --> loss:0.4708, acc:82.46%, val_loss:0.5502, val_acc:82.07%
#  Epoch 143: iteration 106/107
# Epoch 143 --> loss:0.4852, acc:82.20%, val_loss:0.6501, val_acc:74.48%
#  Epoch 144: iteration 106/107
# Epoch 144 --> loss:0.4814, acc:82.58%, val_loss:0.5718, val_acc:78.39%
#  Epoch 145: iteration 106/107
# Epoch 145 --> loss:0.4611, acc:83.25%, val_loss:0.5224, val_acc:79.77%
#  Epoch 146: iteration 106/107
# Epoch 146 --> loss:0.4971, acc:81.62%, val_loss:0.8235, val_acc:68.28%
#  Epoch 147: iteration 106/107
# Epoch 147 --> loss:0.4610, acc:82.26%, val_loss:0.9077, val_acc:63.91%
#  Epoch 148: iteration 106/107
# Epoch 148 --> loss:0.4314, acc:84.35%, val_loss:0.7998, val_acc:68.97%
#  Epoch 149: iteration 106/107
# Epoch 149 --> loss:0.4706, acc:82.64%, val_loss:0.5205, val_acc:83.22%
#  Epoch 150: iteration 106/107
# Epoch 150 --> loss:0.4578, acc:82.70%, val_loss:0.6549, val_acc:74.71%
#  Epoch 151: iteration 106/107
# Epoch 151 --> loss:0.4627, acc:82.64%, val_loss:0.5729, val_acc:79.31%
#  Epoch 152: iteration 106/107
# Epoch 152 --> loss:0.4539, acc:83.48%, val_loss:0.5035, val_acc:82.76%
#  Epoch 153: iteration 106/107
# Epoch 153 --> loss:0.4622, acc:82.61%, val_loss:0.5217, val_acc:83.91%
#  Epoch 154: iteration 106/107
# Epoch 154 --> loss:0.4605, acc:82.75%, val_loss:0.7668, val_acc:68.74%
#  Epoch 155: iteration 106/107
# Epoch 155 --> loss:0.4353, acc:83.07%, val_loss:0.5954, val_acc:77.93%
#  Epoch 156: iteration 106/107
# Epoch 156 --> loss:0.4665, acc:82.87%, val_loss:0.4848, val_acc:82.99%
#  Epoch 157: iteration 106/107
# Epoch 157 --> loss:0.4236, acc:84.17%, val_loss:0.7080, val_acc:73.56%
#  Epoch 158: iteration 106/107
# Epoch 158 --> loss:0.4598, acc:82.87%, val_loss:0.5659, val_acc:77.01%
#  Epoch 159: iteration 106/107
# Epoch 159 --> loss:0.4373, acc:84.09%, val_loss:0.7743, val_acc:68.51%
#  Epoch 160: iteration 106/107
# Epoch 160 --> loss:0.4358, acc:84.12%, val_loss:0.5189, val_acc:80.69%
#  Epoch 161: iteration 106/107
# Epoch 161 --> loss:0.4363, acc:83.74%, val_loss:0.4166, val_acc:85.98%
#  Epoch 162: iteration 106/107
# Epoch 162 --> loss:0.4505, acc:82.64%, val_loss:0.8178, val_acc:67.82%
#  Epoch 163: iteration 106/107
# Epoch 163 --> loss:0.4219, acc:84.20%, val_loss:0.6050, val_acc:76.78%
#  Epoch 164: iteration 106/107
# Epoch 164 --> loss:0.3994, acc:84.75%, val_loss:0.4873, val_acc:82.30%
#  Epoch 165: iteration 106/107
# Epoch 165 --> loss:0.4496, acc:83.65%, val_loss:0.5504, val_acc:81.15%
#  Epoch 166: iteration 106/107
# Epoch 166 --> loss:0.4143, acc:85.42%, val_loss:0.5848, val_acc:79.08%
#  Epoch 167: iteration 106/107
# Epoch 167 --> loss:0.4334, acc:84.17%, val_loss:0.7906, val_acc:71.26%
#  Epoch 168: iteration 106/107
# Epoch 168 --> loss:0.4184, acc:84.29%, val_loss:0.7903, val_acc:71.95%
#  Epoch 169: iteration 106/107
# Epoch 169 --> loss:0.4431, acc:83.68%, val_loss:0.7548, val_acc:70.80%
#  Epoch 170: iteration 106/107
# Epoch 170 --> loss:0.4188, acc:84.61%, val_loss:0.5062, val_acc:81.38%
#  Epoch 171: iteration 106/107
# Epoch 171 --> loss:0.4188, acc:84.32%, val_loss:0.6804, val_acc:76.55%
#  Epoch 172: iteration 106/107
# Epoch 172 --> loss:0.4043, acc:84.35%, val_loss:0.5016, val_acc:82.76%
#  Epoch 173: iteration 106/107
# Epoch 173 --> loss:0.4143, acc:84.75%, val_loss:0.6393, val_acc:74.94%
#  Epoch 174: iteration 106/107
# Epoch 174 --> loss:0.4243, acc:84.00%, val_loss:0.5731, val_acc:79.31%
#  Epoch 175: iteration 106/107
# Epoch 175 --> loss:0.4070, acc:85.04%, val_loss:0.7636, val_acc:70.57%
#  Epoch 176: iteration 106/107
# Epoch 176 --> loss:0.4162, acc:84.67%, val_loss:0.4164, val_acc:86.90%
#  Epoch 177: iteration 106/107
# Epoch 177 --> loss:0.3962, acc:85.07%, val_loss:0.6404, val_acc:73.79%
#  Epoch 178: iteration 106/107
# Epoch 178 --> loss:0.4262, acc:84.32%, val_loss:0.5780, val_acc:77.70%
#  Epoch 179: iteration 106/107
# Epoch 179 --> loss:0.3993, acc:85.39%, val_loss:0.5049, val_acc:83.45%
#  Epoch 180: iteration 106/107
# Epoch 180 --> loss:0.3752, acc:86.23%, val_loss:0.6205, val_acc:75.86%
#  Epoch 181: iteration 106/107
# Epoch 181 --> loss:0.4043, acc:85.19%, val_loss:0.5673, val_acc:79.31%
#  Epoch 182: iteration 106/107
# Epoch 182 --> loss:0.3820, acc:86.55%, val_loss:0.7885, val_acc:68.28%
#  Epoch 183: iteration 106/107
# Epoch 183 --> loss:0.3943, acc:85.83%, val_loss:0.5309, val_acc:80.69%
#  Epoch 184: iteration 106/107
# Epoch 184 --> loss:0.3667, acc:86.49%, val_loss:0.4693, val_acc:83.68%
#  Epoch 185: iteration 106/107
# Epoch 185 --> loss:0.3828, acc:86.26%, val_loss:0.5311, val_acc:80.46%
#  Epoch 186: iteration 106/107
# Epoch 186 --> loss:0.4039, acc:84.72%, val_loss:0.5444, val_acc:81.38%
#  Epoch 187: iteration 106/107
# Epoch 187 --> loss:0.3882, acc:85.77%, val_loss:0.4870, val_acc:82.76%
#  Epoch 188: iteration 106/107
# Epoch 188 --> loss:0.3649, acc:86.26%, val_loss:0.6599, val_acc:71.03%
#  Epoch 189: iteration 106/107
# Epoch 189 --> loss:0.3800, acc:86.23%, val_loss:0.6426, val_acc:74.71%
#  Epoch 190: iteration 106/107
# Epoch 190 --> loss:0.3771, acc:86.38%, val_loss:0.7266, val_acc:71.72%
#  Epoch 191: iteration 106/107
# Epoch 191 --> loss:0.3973, acc:84.81%, val_loss:0.5947, val_acc:78.85%
#  Epoch 192: iteration 106/107
# Epoch 192 --> loss:0.3690, acc:86.58%, val_loss:0.7512, val_acc:71.72%
#  Epoch 193: iteration 106/107
# Epoch 193 --> loss:0.3871, acc:85.91%, val_loss:0.5249, val_acc:80.92%
#  Epoch 194: iteration 106/107
# Epoch 194 --> loss:0.3658, acc:86.64%, val_loss:0.7640, val_acc:70.57%
#  Epoch 195: iteration 106/107
# Epoch 195 --> loss:0.4115, acc:84.78%, val_loss:0.6162, val_acc:77.01%
#  Epoch 196: iteration 106/107
# Epoch 196 --> loss:0.3968, acc:85.77%, val_loss:0.4048, val_acc:87.59%
#  Epoch 197: iteration 106/107
# Epoch 197 --> loss:0.3632, acc:86.78%, val_loss:0.5685, val_acc:79.77%
#  Epoch 198: iteration 106/107
# Epoch 198 --> loss:0.3528, acc:86.96%, val_loss:0.4850, val_acc:84.37%
#  Epoch 199: iteration 106/107
# Epoch 199 --> loss:0.3642, acc:85.74%, val_loss:0.4807, val_acc:82.76%
#  Epoch 200: iteration 106/107
# Epoch 200 --> loss:0.3851, acc:85.45%, val_loss:0.4912, val_acc:83.22%
#  Epoch 201: iteration 106/107
# Epoch 201 --> loss:0.3581, acc:86.38%, val_loss:0.4389, val_acc:87.82%
#  Epoch 202: iteration 106/107
# Epoch 202 --> loss:0.3814, acc:85.97%, val_loss:0.5062, val_acc:82.76%
#  Epoch 203: iteration 106/107
# Epoch 203 --> loss:0.3572, acc:86.43%, val_loss:0.7928, val_acc:68.51%
#  Epoch 204: iteration 106/107
# Epoch 204 --> loss:0.3721, acc:86.09%, val_loss:0.4689, val_acc:83.45%
#  Epoch 205: iteration 106/107
# Epoch 205 --> loss:0.3752, acc:86.70%, val_loss:0.5324, val_acc:81.61%
#  Epoch 206: iteration 106/107
# Epoch 206 --> loss:0.3299, acc:88.00%, val_loss:0.4019, val_acc:88.74%
#  Epoch 207: iteration 106/107
# Epoch 207 --> loss:0.3333, acc:87.36%, val_loss:0.6896, val_acc:74.48%
#  Epoch 208: iteration 106/107
# Epoch 208 --> loss:0.3593, acc:86.90%, val_loss:0.6255, val_acc:74.94%
#  Epoch 209: iteration 106/107
# Epoch 209 --> loss:0.3786, acc:85.65%, val_loss:0.5433, val_acc:81.38%
#  Epoch 210: iteration 106/107
# Epoch 210 --> loss:0.3388, acc:87.68%, val_loss:0.5252, val_acc:81.15%
#  Epoch 211: iteration 106/107
# Epoch 211 --> loss:0.3282, acc:88.09%, val_loss:0.4402, val_acc:83.22%
#  Epoch 212: iteration 106/107
# Epoch 212 --> loss:0.3474, acc:87.28%, val_loss:0.6235, val_acc:78.16%
#  Epoch 213: iteration 106/107
# Epoch 213 --> loss:0.3523, acc:86.29%, val_loss:0.5205, val_acc:80.92%
#  Epoch 214: iteration 106/107
# Epoch 214 --> loss:0.3493, acc:86.72%, val_loss:0.4071, val_acc:87.36%
#  Epoch 215: iteration 106/107
# Epoch 215 --> loss:0.3652, acc:86.72%, val_loss:0.5158, val_acc:83.68%
#  Epoch 216: iteration 106/107
# Epoch 216 --> loss:0.3564, acc:86.67%, val_loss:0.3893, val_acc:88.51%
#  Epoch 217: iteration 106/107
# Epoch 217 --> loss:0.3653, acc:86.78%, val_loss:0.4329, val_acc:86.21%
#  Epoch 218: iteration 106/107
# Epoch 218 --> loss:0.3408, acc:87.39%, val_loss:0.5075, val_acc:81.84%
#  Epoch 219: iteration 106/107
# Epoch 219 --> loss:0.3449, acc:87.22%, val_loss:0.4756, val_acc:85.06%
#  Epoch 220: iteration 106/107
# Epoch 220 --> loss:0.3283, acc:87.71%, val_loss:0.3817, val_acc:88.05%
#  Epoch 221: iteration 106/107
# Epoch 221 --> loss:0.3262, acc:87.88%, val_loss:0.3891, val_acc:87.36%
#  Epoch 222: iteration 106/107
# Epoch 222 --> loss:0.3152, acc:88.87%, val_loss:0.4354, val_acc:83.91%
#  Epoch 223: iteration 106/107
# Epoch 223 --> loss:0.3559, acc:86.70%, val_loss:0.3778, val_acc:88.51%
#  Epoch 224: iteration 106/107
# Epoch 224 --> loss:0.3559, acc:86.75%, val_loss:0.4941, val_acc:82.76%
#  Epoch 225: iteration 106/107
# Epoch 225 --> loss:0.3627, acc:86.32%, val_loss:0.5702, val_acc:78.39%
#  Epoch 226: iteration 106/107
# Epoch 226 --> loss:0.3449, acc:86.93%, val_loss:0.4444, val_acc:84.37%
#  Epoch 227: iteration 106/107
# Epoch 227 --> loss:0.3346, acc:87.71%, val_loss:0.3611, val_acc:88.74%
#  Epoch 228: iteration 106/107
# Epoch 228 --> loss:0.3348, acc:88.12%, val_loss:0.5848, val_acc:78.39%
#  Epoch 229: iteration 106/107
# Epoch 229 --> loss:0.3549, acc:87.10%, val_loss:0.4714, val_acc:85.29%
#  Epoch 230: iteration 106/107
# Epoch 230 --> loss:0.3019, acc:88.61%, val_loss:0.6562, val_acc:74.94%
#  Epoch 231: iteration 106/107
# Epoch 231 --> loss:0.3639, acc:86.41%, val_loss:0.5217, val_acc:82.30%
#  Epoch 232: iteration 106/107
# Epoch 232 --> loss:0.3333, acc:87.86%, val_loss:0.8144, val_acc:69.20%
#  Epoch 233: iteration 106/107
# Epoch 233 --> loss:0.3325, acc:87.51%, val_loss:0.6249, val_acc:78.16%
#  Epoch 234: iteration 106/107
# Epoch 234 --> loss:0.3530, acc:87.22%, val_loss:0.6209, val_acc:78.16%
#  Epoch 235: iteration 106/107
# Epoch 235 --> loss:0.3471, acc:87.30%, val_loss:0.4448, val_acc:82.53%
#  Epoch 236: iteration 106/107
# Epoch 236 --> loss:0.3325, acc:87.88%, val_loss:0.4251, val_acc:85.98%
#  Epoch 237: iteration 106/107
# Epoch 237 --> loss:0.3389, acc:88.14%, val_loss:0.4448, val_acc:84.14%
#  Epoch 238: iteration 106/107
# Epoch 238 --> loss:0.3141, acc:88.58%, val_loss:0.3725, val_acc:86.67%
#  Epoch 239: iteration 106/107
# Epoch 239 --> loss:0.3166, acc:88.00%, val_loss:0.5997, val_acc:77.24%
#  Epoch 240: iteration 106/107
# Epoch 240 --> loss:0.3490, acc:87.07%, val_loss:0.5535, val_acc:81.38%
#  Epoch 241: iteration 106/107
# Epoch 241 --> loss:0.2859, acc:89.74%, val_loss:0.3391, val_acc:89.20%
#  Epoch 242: iteration 106/107
# Epoch 242 --> loss:0.3075, acc:88.46%, val_loss:0.5347, val_acc:79.54%
#  Epoch 243: iteration 106/107
# Epoch 243 --> loss:0.3356, acc:87.45%, val_loss:0.4226, val_acc:85.29%
#  Epoch 244: iteration 106/107
# Epoch 244 --> loss:0.3180, acc:88.58%, val_loss:0.5313, val_acc:79.08%
#  Epoch 245: iteration 106/107
# Epoch 245 --> loss:0.3164, acc:88.49%, val_loss:0.5629, val_acc:80.00%
#  Epoch 246: iteration 106/107
# Epoch 246 --> loss:0.3190, acc:88.67%, val_loss:0.4014, val_acc:86.90%
#  Epoch 247: iteration 106/107
# Epoch 247 --> loss:0.2989, acc:88.41%, val_loss:0.3871, val_acc:88.28%
#  Epoch 248: iteration 106/107
# Epoch 248 --> loss:0.3516, acc:86.90%, val_loss:0.5624, val_acc:79.77%
#  Epoch 249: iteration 106/107
# Epoch 249 --> loss:0.3161, acc:88.61%, val_loss:0.5347, val_acc:78.85%
#  Epoch 250: iteration 106/107
# Epoch 250 --> loss:0.3425, acc:87.28%, val_loss:0.3951, val_acc:86.21%
#  Epoch 251: iteration 106/107
# Epoch 251 --> loss:0.2961, acc:88.84%, val_loss:0.4328, val_acc:86.21%
#  Epoch 252: iteration 106/107
# Epoch 252 --> loss:0.3094, acc:88.12%, val_loss:0.5006, val_acc:79.77%
#  Epoch 253: iteration 106/107
# Epoch 253 --> loss:0.3107, acc:88.70%, val_loss:0.3792, val_acc:86.67%
#  Epoch 254: iteration 106/107
# Epoch 254 --> loss:0.3152, acc:88.64%, val_loss:0.4107, val_acc:86.21%
#  Epoch 255: iteration 106/107
# Epoch 255 --> loss:0.3323, acc:87.57%, val_loss:0.4900, val_acc:80.92%
#  Epoch 256: iteration 106/107
# Epoch 256 --> loss:0.3135, acc:87.54%, val_loss:0.3761, val_acc:88.74%
#  Epoch 257: iteration 106/107
# Epoch 257 --> loss:0.2925, acc:89.45%, val_loss:0.4674, val_acc:83.68%
#  Epoch 258: iteration 106/107
# Epoch 258 --> loss:0.3291, acc:88.46%, val_loss:0.2970, val_acc:92.87%
#  Epoch 259: iteration 106/107
# Epoch 259 --> loss:0.2899, acc:89.51%, val_loss:0.4187, val_acc:85.75%
#  Epoch 260: iteration 106/107
# Epoch 260 --> loss:0.2997, acc:89.19%, val_loss:0.2790, val_acc:92.18%
#  Epoch 261: iteration 106/107
# Epoch 261 --> loss:0.3053, acc:89.10%, val_loss:0.4315, val_acc:82.53%
#  Epoch 262: iteration 106/107
# Epoch 262 --> loss:0.3312, acc:87.42%, val_loss:0.6070, val_acc:76.55%
#  Epoch 263: iteration 106/107
# Epoch 263 --> loss:0.3126, acc:89.01%, val_loss:0.4253, val_acc:81.84%
#  Epoch 264: iteration 106/107
# Epoch 264 --> loss:0.3297, acc:88.14%, val_loss:0.3770, val_acc:87.36%
#  Epoch 265: iteration 106/107
# Epoch 265 --> loss:0.2981, acc:88.81%, val_loss:0.3360, val_acc:89.20%
#  Epoch 266: iteration 106/107
# Epoch 266 --> loss:0.3067, acc:88.14%, val_loss:0.3439, val_acc:90.57%
#  Epoch 267: iteration 106/107
# Epoch 267 --> loss:0.3000, acc:88.72%, val_loss:0.2701, val_acc:93.33%
#  Epoch 268: iteration 106/107
# Epoch 268 --> loss:0.3130, acc:87.94%, val_loss:0.4587, val_acc:82.53%
#  Epoch 269: iteration 106/107
# Epoch 269 --> loss:0.3038, acc:88.55%, val_loss:0.4283, val_acc:84.37%
#  Epoch 270: iteration 106/107
# Epoch 270 --> loss:0.3106, acc:88.61%, val_loss:0.3999, val_acc:87.36%
#  Epoch 271: iteration 106/107
# Epoch 271 --> loss:0.2994, acc:88.64%, val_loss:0.4604, val_acc:84.83%
#  Epoch 272: iteration 106/107
# Epoch 272 --> loss:0.2825, acc:89.42%, val_loss:0.4233, val_acc:85.52%
#  Epoch 273: iteration 106/107
# Epoch 273 --> loss:0.3151, acc:88.20%, val_loss:0.5283, val_acc:80.23%
#  Epoch 274: iteration 106/107
# Epoch 274 --> loss:0.3088, acc:88.46%, val_loss:0.4301, val_acc:85.06%
#  Epoch 275: iteration 106/107
# Epoch 275 --> loss:0.2859, acc:89.36%, val_loss:0.4563, val_acc:83.68%
#  Epoch 276: iteration 106/107
# Epoch 276 --> loss:0.3132, acc:88.78%, val_loss:0.5287, val_acc:81.84%
#  Epoch 277: iteration 106/107
# Epoch 277 --> loss:0.3101, acc:88.35%, val_loss:0.3990, val_acc:86.90%
#  Epoch 278: iteration 106/107
# Epoch 278 --> loss:0.3014, acc:88.49%, val_loss:0.2833, val_acc:93.10%
#  Epoch 279: iteration 106/107
# Epoch 279 --> loss:0.2648, acc:90.00%, val_loss:0.5636, val_acc:78.16%
#  Epoch 280: iteration 106/107
# Epoch 280 --> loss:0.2751, acc:89.94%, val_loss:0.5545, val_acc:80.23%
#  Epoch 281: iteration 106/107
# Epoch 281 --> loss:0.2927, acc:89.59%, val_loss:0.4103, val_acc:86.90%
#  Epoch 282: iteration 106/107
# Epoch 282 --> loss:0.3145, acc:88.38%, val_loss:0.5300, val_acc:81.38%
#  Epoch 283: iteration 106/107
# Epoch 283 --> loss:0.2908, acc:89.59%, val_loss:0.4889, val_acc:82.30%
#  Epoch 284: iteration 106/107
# Epoch 284 --> loss:0.3085, acc:88.67%, val_loss:0.7463, val_acc:72.41%
#  Epoch 285: iteration 106/107
# Epoch 285 --> loss:0.3115, acc:88.29%, val_loss:0.4436, val_acc:84.37%
#  Epoch 286: iteration 106/107
# Epoch 286 --> loss:0.2721, acc:89.88%, val_loss:0.4946, val_acc:80.00%
#  Epoch 287: iteration 106/107
# Epoch 287 --> loss:0.2996, acc:88.55%, val_loss:0.5286, val_acc:79.31%
#  Epoch 288: iteration 106/107
# Epoch 288 --> loss:0.3076, acc:88.84%, val_loss:0.3023, val_acc:89.89%
#  Epoch 289: iteration 106/107
# Epoch 289 --> loss:0.3011, acc:89.16%, val_loss:0.6357, val_acc:77.24%
#  Epoch 290: iteration 106/107
# Epoch 290 --> loss:0.3023, acc:88.87%, val_loss:0.3544, val_acc:90.57%
#  Epoch 291: iteration 106/107
# Epoch 291 --> loss:0.2987, acc:89.16%, val_loss:0.3853, val_acc:88.05%
#  Epoch 292: iteration 106/107
# Epoch 292 --> loss:0.2950, acc:88.70%, val_loss:0.6883, val_acc:72.18%
#  Epoch 293: iteration 106/107
# Epoch 293 --> loss:0.2819, acc:89.80%, val_loss:0.3225, val_acc:89.66%
#  Epoch 294: iteration 106/107
# Epoch 294 --> loss:0.2922, acc:89.16%, val_loss:0.3813, val_acc:87.82%
#  Epoch 295: iteration 106/107
# Epoch 295 --> loss:0.2865, acc:89.19%, val_loss:0.3133, val_acc:91.49%
#  Epoch 296: iteration 106/107
# Epoch 296 --> loss:0.2923, acc:89.71%, val_loss:0.4070, val_acc:87.82%
#  Epoch 297: iteration 106/107
# Epoch 297 --> loss:0.2581, acc:90.70%, val_loss:0.3256, val_acc:88.51%
#  Epoch 298: iteration 106/107
# Epoch 298 --> loss:0.2730, acc:89.68%, val_loss:0.3372, val_acc:90.11%
#  Epoch 299: iteration 106/107
# Epoch 299 --> loss:0.2772, acc:90.00%, val_loss:0.3784, val_acc:87.82%
#  Epoch 300: iteration 106/107
# Epoch 300 --> loss:0.2841, acc:89.28%, val_loss:0.4203, val_acc:85.75%
#  Epoch 301: iteration 106/107
# Epoch 301 --> loss:0.2854, acc:89.88%, val_loss:0.4528, val_acc:82.99%
#  Epoch 302: iteration 106/107
# Epoch 302 --> loss:0.2651, acc:90.41%, val_loss:0.2899, val_acc:90.57%
#  Epoch 303: iteration 106/107
# Epoch 303 --> loss:0.2903, acc:89.33%, val_loss:0.3134, val_acc:91.03%
#  Epoch 304: iteration 106/107
# Epoch 304 --> loss:0.2886, acc:89.65%, val_loss:0.5154, val_acc:81.84%
#  Epoch 305: iteration 106/107
# Epoch 305 --> loss:0.2830, acc:89.33%, val_loss:0.4366, val_acc:83.45%
#  Epoch 306: iteration 106/107
# Epoch 306 --> loss:0.3034, acc:88.32%, val_loss:0.3886, val_acc:88.74%
#  Epoch 307: iteration 106/107
# Epoch 307 --> loss:0.2732, acc:89.45%, val_loss:0.2761, val_acc:91.03%
#  Epoch 308: iteration 106/107
# Epoch 308 --> loss:0.2873, acc:89.19%, val_loss:0.4441, val_acc:84.60%
#  Epoch 309: iteration 106/107
# Epoch 309 --> loss:0.3045, acc:88.70%, val_loss:0.4207, val_acc:84.60%
#  Epoch 310: iteration 106/107
# Epoch 310 --> loss:0.2992, acc:88.81%, val_loss:0.5267, val_acc:82.99%
#  Epoch 311: iteration 106/107
# Epoch 311 --> loss:0.2778, acc:89.19%, val_loss:0.3057, val_acc:91.95%
#  Epoch 312: iteration 106/107
# Epoch 312 --> loss:0.3096, acc:89.19%, val_loss:0.6449, val_acc:76.09%
#  Epoch 313: iteration 106/107
# Epoch 313 --> loss:0.2893, acc:89.36%, val_loss:0.4395, val_acc:87.13%
#  Epoch 314: iteration 106/107
# Epoch 314 --> loss:0.2874, acc:88.96%, val_loss:0.5304, val_acc:80.69%
#  Epoch 315: iteration 106/107
# Epoch 315 --> loss:0.2815, acc:89.94%, val_loss:0.3181, val_acc:90.80%
#  Epoch 316: iteration 106/107
# Epoch 316 --> loss:0.2897, acc:89.19%, val_loss:0.5157, val_acc:80.23%
#  Epoch 317: iteration 106/107
# Epoch 317 --> loss:0.2686, acc:90.17%, val_loss:0.4437, val_acc:84.37%
#  Epoch 318: iteration 106/107
# Epoch 318 --> loss:0.2643, acc:90.52%, val_loss:0.5428, val_acc:79.31%
#  Epoch 319: iteration 106/107
# Epoch 319 --> loss:0.2890, acc:88.93%, val_loss:0.3662, val_acc:88.97%
#  Epoch 320: iteration 106/107
# Epoch 320 --> loss:0.2770, acc:90.12%, val_loss:0.5296, val_acc:81.61%
#  Epoch 321: iteration 106/107
# Epoch 321 --> loss:0.2709, acc:90.32%, val_loss:0.3804, val_acc:88.28%
#  Epoch 322: iteration 106/107
# Epoch 322 --> loss:0.2995, acc:89.22%, val_loss:0.3835, val_acc:85.98%
#  Epoch 323: iteration 106/107
# Epoch 323 --> loss:0.2879, acc:89.45%, val_loss:0.2613, val_acc:92.41%
#  Epoch 324: iteration 106/107
# Epoch 324 --> loss:0.2619, acc:90.61%, val_loss:0.3418, val_acc:89.43%
#  Epoch 325: iteration 106/107
# Epoch 325 --> loss:0.2792, acc:89.86%, val_loss:0.6194, val_acc:77.47%
#  Epoch 326: iteration 106/107
# Epoch 326 --> loss:0.2599, acc:90.32%, val_loss:0.4921, val_acc:81.38%
#  Epoch 327: iteration 106/107
# Epoch 327 --> loss:0.2912, acc:89.19%, val_loss:0.4901, val_acc:83.91%
#  Epoch 328: iteration 106/107
# Epoch 328 --> loss:0.2616, acc:90.52%, val_loss:0.3267, val_acc:89.89%
#  Epoch 329: iteration 106/107
# Epoch 329 --> loss:0.2810, acc:89.59%, val_loss:0.3105, val_acc:89.89%
#  Epoch 330: iteration 106/107
# Epoch 330 --> loss:0.2776, acc:90.03%, val_loss:0.3171, val_acc:90.57%
#  Epoch 331: iteration 106/107
# Epoch 331 --> loss:0.2736, acc:89.33%, val_loss:0.5646, val_acc:77.47%
#  Epoch 332: iteration 106/107
# Epoch 332 --> loss:0.2733, acc:89.51%, val_loss:0.2563, val_acc:93.56%
#  Epoch 333: iteration 106/107
# Epoch 333 --> loss:0.2603, acc:90.00%, val_loss:0.2714, val_acc:91.49%
#  Epoch 334: iteration 106/107
# Epoch 334 --> loss:0.2689, acc:89.97%, val_loss:0.3145, val_acc:89.89%
#  Epoch 335: iteration 106/107
# Epoch 335 --> loss:0.2563, acc:90.58%, val_loss:0.3025, val_acc:92.18%
#  Epoch 336: iteration 106/107
# Epoch 336 --> loss:0.2924, acc:89.59%, val_loss:0.4097, val_acc:84.83%
#  Epoch 337: iteration 106/107
# Epoch 337 --> loss:0.2802, acc:89.30%, val_loss:0.5175, val_acc:81.38%
#  Epoch 338: iteration 106/107
# Epoch 338 --> loss:0.2766, acc:89.88%, val_loss:0.4383, val_acc:84.37%
#  Epoch 339: iteration 106/107
# Epoch 339 --> loss:0.2588, acc:90.17%, val_loss:0.3700, val_acc:87.59%
#  Epoch 340: iteration 106/107
# Epoch 340 --> loss:0.2702, acc:89.91%, val_loss:0.4577, val_acc:82.53%
#  Epoch 341: iteration 106/107
# Epoch 341 --> loss:0.2685, acc:90.29%, val_loss:0.4105, val_acc:88.28%
#  Epoch 342: iteration 106/107
# Epoch 342 --> loss:0.2824, acc:89.83%, val_loss:0.5109, val_acc:81.84%
#  Epoch 343: iteration 106/107
# Epoch 343 --> loss:0.2667, acc:90.12%, val_loss:0.4129, val_acc:84.14%
#  Epoch 344: iteration 106/107
# Epoch 344 --> loss:0.2499, acc:90.93%, val_loss:0.3058, val_acc:90.80%
#  Epoch 345: iteration 106/107
# Epoch 345 --> loss:0.2536, acc:90.49%, val_loss:0.4118, val_acc:87.36%
#  Epoch 346: iteration 106/107
# Epoch 346 --> loss:0.2655, acc:90.49%, val_loss:0.3446, val_acc:89.89%
#  Epoch 347: iteration 106/107
# Epoch 347 --> loss:0.2450, acc:90.81%, val_loss:0.4995, val_acc:81.15%
#  Epoch 348: iteration 106/107
# Epoch 348 --> loss:0.2554, acc:90.61%, val_loss:0.4558, val_acc:81.61%
#  Epoch 349: iteration 106/107
# Epoch 349 --> loss:0.2847, acc:89.13%, val_loss:0.4790, val_acc:84.37%
#  Epoch 350: iteration 106/107
# Epoch 350 --> loss:0.2643, acc:90.38%, val_loss:0.5555, val_acc:79.31%
#  Epoch 351: iteration 106/107
# Epoch 351 --> loss:0.2761, acc:90.29%, val_loss:0.4707, val_acc:83.91%
#  Epoch 352: iteration 106/107
# Epoch 352 --> loss:0.2529, acc:90.41%, val_loss:0.4045, val_acc:86.21%
#  Epoch 353: iteration 106/107
# Epoch 353 --> loss:0.2683, acc:90.06%, val_loss:0.2805, val_acc:91.49%
#  Epoch 354: iteration 106/107
# Epoch 354 --> loss:0.2474, acc:90.58%, val_loss:0.4533, val_acc:83.45%
#  Epoch 355: iteration 106/107
# Epoch 355 --> loss:0.2695, acc:90.06%, val_loss:0.2885, val_acc:90.80%
#  Epoch 356: iteration 106/107
# Epoch 356 --> loss:0.2579, acc:90.61%, val_loss:0.3066, val_acc:91.03%
#  Epoch 357: iteration 106/107
# Epoch 357 --> loss:0.2705, acc:89.16%, val_loss:0.3673, val_acc:88.97%
#  Epoch 358: iteration 106/107
# Epoch 358 --> loss:0.2461, acc:91.04%, val_loss:0.3548, val_acc:89.20%
#  Epoch 359: iteration 106/107
# Epoch 359 --> loss:0.2740, acc:89.65%, val_loss:0.4350, val_acc:84.37%
#  Epoch 360: iteration 106/107
# Epoch 360 --> loss:0.2790, acc:89.77%, val_loss:0.2728, val_acc:93.10%
#  Epoch 361: iteration 106/107
# Epoch 361 --> loss:0.2560, acc:90.72%, val_loss:0.3069, val_acc:90.11%
#  Epoch 362: iteration 106/107
# Epoch 362 --> loss:0.2741, acc:89.57%, val_loss:0.3374, val_acc:87.59%
#  Epoch 363: iteration 106/107
# Epoch 363 --> loss:0.2447, acc:90.90%, val_loss:0.4098, val_acc:86.44%
#  Epoch 364: iteration 106/107
# Epoch 364 --> loss:0.2722, acc:90.23%, val_loss:0.2957, val_acc:92.18%
#  Epoch 365: iteration 106/107
# Epoch 365 --> loss:0.2532, acc:90.93%, val_loss:0.4791, val_acc:84.83%
#  Epoch 366: iteration 106/107
# Epoch 366 --> loss:0.2637, acc:89.62%, val_loss:0.2718, val_acc:94.02%
#  Epoch 367: iteration 106/107
# Epoch 367 --> loss:0.2704, acc:89.74%, val_loss:0.3142, val_acc:88.51%
#  Epoch 368: iteration 106/107
# Epoch 368 --> loss:0.2694, acc:89.97%, val_loss:0.3592, val_acc:85.29%
#  Epoch 369: iteration 106/107
# Epoch 369 --> loss:0.2589, acc:90.55%, val_loss:0.3110, val_acc:89.43%
#  Epoch 370: iteration 106/107
# Epoch 370 --> loss:0.2689, acc:90.52%, val_loss:0.3919, val_acc:86.21%
#  Epoch 371: iteration 106/107
# Epoch 371 --> loss:0.2726, acc:90.35%, val_loss:0.2618, val_acc:91.95%
#  Epoch 372: iteration 106/107
# Epoch 372 --> loss:0.2262, acc:91.71%, val_loss:0.4922, val_acc:81.15%
#  Epoch 373: iteration 106/107
# Epoch 373 --> loss:0.2586, acc:90.52%, val_loss:0.3839, val_acc:87.13%
#  Epoch 374: iteration 106/107
# Epoch 374 --> loss:0.2737, acc:90.29%, val_loss:0.3599, val_acc:87.82%
#  Epoch 375: iteration 106/107
# Epoch 375 --> loss:0.2660, acc:89.68%, val_loss:0.3563, val_acc:88.74%
#  Epoch 376: iteration 106/107
# Epoch 376 --> loss:0.2657, acc:90.03%, val_loss:0.2916, val_acc:91.03%
#  Epoch 377: iteration 106/107
# Epoch 377 --> loss:0.2474, acc:90.78%, val_loss:0.2439, val_acc:92.41%
#  Epoch 378: iteration 106/107
# Epoch 378 --> loss:0.2567, acc:90.29%, val_loss:0.3374, val_acc:90.34%
#  Epoch 379: iteration 106/107
# Epoch 379 --> loss:0.2690, acc:89.42%, val_loss:0.3201, val_acc:90.57%
#  Epoch 380: iteration 106/107
# Epoch 380 --> loss:0.2835, acc:90.00%, val_loss:0.3785, val_acc:88.97%
#  Epoch 381: iteration 106/107
# Epoch 381 --> loss:0.2352, acc:91.22%, val_loss:0.2805, val_acc:91.95%
#  Epoch 382: iteration 106/107
# Epoch 382 --> loss:0.2635, acc:90.14%, val_loss:0.6830, val_acc:79.08%
#  Epoch 383: iteration 106/107
# Epoch 383 --> loss:0.2505, acc:90.81%, val_loss:0.3475, val_acc:90.34%
#  Epoch 384: iteration 106/107
# Epoch 384 --> loss:0.2432, acc:90.96%, val_loss:0.4275, val_acc:84.83%
#  Epoch 385: iteration 106/107
# Epoch 385 --> loss:0.2412, acc:91.04%, val_loss:0.3454, val_acc:88.51%
#  Epoch 386: iteration 106/107
# Epoch 386 --> loss:0.2396, acc:90.78%, val_loss:0.2775, val_acc:91.72%
#  Epoch 387: iteration 106/107
# Epoch 387 --> loss:0.2491, acc:90.43%, val_loss:0.3437, val_acc:88.28%
#  Epoch 388: iteration 106/107
# Epoch 388 --> loss:0.2451, acc:90.87%, val_loss:0.3724, val_acc:87.82%
#  Epoch 389: iteration 106/107
# Epoch 389 --> loss:0.2782, acc:89.80%, val_loss:0.3520, val_acc:89.66%
#  Epoch 390: iteration 106/107
# Epoch 390 --> loss:0.2545, acc:90.75%, val_loss:0.3807, val_acc:86.44%
#  Epoch 391: iteration 106/107
# Epoch 391 --> loss:0.2533, acc:90.81%, val_loss:0.2578, val_acc:92.41%
#  Epoch 392: iteration 106/107
# Epoch 392 --> loss:0.2576, acc:90.43%, val_loss:0.3486, val_acc:88.51%
#  Epoch 393: iteration 106/107
# Epoch 393 --> loss:0.2674, acc:90.32%, val_loss:0.3667, val_acc:87.82%
#  Epoch 394: iteration 106/107
# Epoch 394 --> loss:0.2430, acc:91.68%, val_loss:0.4503, val_acc:85.06%
#  Epoch 395: iteration 106/107
# Epoch 395 --> loss:0.2360, acc:90.84%, val_loss:0.3048, val_acc:90.11%
#  Epoch 396: iteration 106/107
# Epoch 396 --> loss:0.2861, acc:89.54%, val_loss:0.3716, val_acc:86.90%
#  Epoch 397: iteration 106/107
# Epoch 397 --> loss:0.2545, acc:90.41%, val_loss:0.3425, val_acc:89.20%
#  Epoch 398: iteration 106/107
# Epoch 398 --> loss:0.2629, acc:89.74%, val_loss:0.3152, val_acc:91.26%
#  Epoch 399: iteration 106/107
# Epoch 399 --> loss:0.2640, acc:90.23%, val_loss:0.4809, val_acc:82.53%
#  Epoch 400: iteration 106/107
# Epoch 400 --> loss:0.2346, acc:91.45%, val_loss:0.4857, val_acc:82.76%
#  Epoch 401: iteration 106/107
# Epoch 401 --> loss:0.2586, acc:90.55%, val_loss:0.2886, val_acc:90.57%
#  Epoch 402: iteration 106/107
# Epoch 402 --> loss:0.2568, acc:90.61%, val_loss:0.3407, val_acc:89.66%
#  Epoch 403: iteration 106/107
# Epoch 403 --> loss:0.2416, acc:91.33%, val_loss:0.2687, val_acc:91.03%
#  Epoch 404: iteration 106/107
# Epoch 404 --> loss:0.2430, acc:91.10%, val_loss:0.4165, val_acc:85.29%
#  Epoch 405: iteration 106/107
# Epoch 405 --> loss:0.2469, acc:91.07%, val_loss:0.2859, val_acc:91.95%
#  Epoch 406: iteration 106/107
# Epoch 406 --> loss:0.2570, acc:90.93%, val_loss:0.3334, val_acc:88.74%
#  Epoch 407: iteration 106/107
# Epoch 407 --> loss:0.2605, acc:90.78%, val_loss:0.2341, val_acc:93.56%
#  Epoch 408: iteration 106/107
# Epoch 408 --> loss:0.2332, acc:91.07%, val_loss:0.2224, val_acc:94.71%
#  Epoch 409: iteration 106/107
# Epoch 409 --> loss:0.2565, acc:90.81%, val_loss:0.2973, val_acc:90.80%
#  Epoch 410: iteration 106/107
# Epoch 410 --> loss:0.2577, acc:90.38%, val_loss:0.2698, val_acc:92.64%
#  Epoch 411: iteration 106/107
# Epoch 411 --> loss:0.2458, acc:91.22%, val_loss:0.6217, val_acc:78.16%
#  Epoch 412: iteration 106/107
# Epoch 412 --> loss:0.2266, acc:91.68%, val_loss:0.2293, val_acc:93.56%
#  Epoch 413: iteration 106/107
# Epoch 413 --> loss:0.2344, acc:90.96%, val_loss:0.3862, val_acc:86.21%
#  Epoch 414: iteration 106/107
# Epoch 414 --> loss:0.2413, acc:90.96%, val_loss:0.2018, val_acc:94.48%
#  Epoch 415: iteration 106/107
# Epoch 415 --> loss:0.2628, acc:90.00%, val_loss:0.2531, val_acc:94.02%
#  Epoch 416: iteration 106/107
# Epoch 416 --> loss:0.2658, acc:90.17%, val_loss:0.3503, val_acc:87.59%
#  Epoch 417: iteration 106/107
# Epoch 417 --> loss:0.2479, acc:90.93%, val_loss:0.2306, val_acc:93.56%
#  Epoch 418: iteration 106/107
# Epoch 418 --> loss:0.2601, acc:90.38%, val_loss:0.3587, val_acc:88.74%
#  Epoch 419: iteration 106/107
# Epoch 419 --> loss:0.2441, acc:90.67%, val_loss:0.3969, val_acc:86.90%
#  Epoch 420: iteration 106/107
# Epoch 420 --> loss:0.2308, acc:91.13%, val_loss:0.3591, val_acc:88.05%
#  Epoch 421: iteration 106/107
# Epoch 421 --> loss:0.2272, acc:91.13%, val_loss:0.3122, val_acc:91.72%
#  Epoch 422: iteration 106/107
# Epoch 422 --> loss:0.2641, acc:90.58%, val_loss:0.3376, val_acc:88.05%
#  Epoch 423: iteration 106/107
# Epoch 423 --> loss:0.2419, acc:91.48%, val_loss:0.2754, val_acc:92.18%
#  Epoch 424: iteration 106/107
# Epoch 424 --> loss:0.2589, acc:90.32%, val_loss:0.2860, val_acc:91.49%
#  Epoch 425: iteration 106/107
# Epoch 425 --> loss:0.2506, acc:90.52%, val_loss:0.3555, val_acc:88.51%
#  Epoch 426: iteration 106/107
# Epoch 426 --> loss:0.2649, acc:90.87%, val_loss:0.2599, val_acc:92.87%
#  Epoch 427: iteration 106/107
# Epoch 427 --> loss:0.2683, acc:90.00%, val_loss:0.3539, val_acc:88.28%
#  Epoch 428: iteration 106/107
# Epoch 428 --> loss:0.2638, acc:90.72%, val_loss:0.6022, val_acc:77.01%
#  Epoch 429: iteration 106/107
# Epoch 429 --> loss:0.2451, acc:90.75%, val_loss:0.2819, val_acc:92.18%
#  Epoch 430: iteration 106/107
# Epoch 430 --> loss:0.2397, acc:91.13%, val_loss:0.3249, val_acc:88.97%
#  Epoch 431: iteration 106/107
# Epoch 431 --> loss:0.2558, acc:90.87%, val_loss:0.2872, val_acc:91.49%
#  Epoch 432: iteration 106/107
# Epoch 432 --> loss:0.2521, acc:90.49%, val_loss:0.3535, val_acc:88.28%
#  Epoch 433: iteration 106/107
# Epoch 433 --> loss:0.2486, acc:90.75%, val_loss:0.2281, val_acc:94.02%
#  Epoch 434: iteration 106/107
# Epoch 434 --> loss:0.2803, acc:89.97%, val_loss:0.3457, val_acc:87.59%
#  Epoch 435: iteration 106/107
# Epoch 435 --> loss:0.2486, acc:90.99%, val_loss:0.2352, val_acc:92.18%
#  Epoch 436: iteration 106/107
# Epoch 436 --> loss:0.2376, acc:91.28%, val_loss:0.3791, val_acc:87.13%
#  Epoch 437: iteration 106/107
# Epoch 437 --> loss:0.2521, acc:91.07%, val_loss:0.3489, val_acc:88.51%
#  Epoch 438: iteration 106/107
# Epoch 438 --> loss:0.2385, acc:91.42%, val_loss:0.3159, val_acc:90.57%
#  Epoch 439: iteration 106/107
# Epoch 439 --> loss:0.2299, acc:91.59%, val_loss:0.4606, val_acc:85.06%
#  Epoch 440: iteration 106/107
# Epoch 440 --> loss:0.2343, acc:91.48%, val_loss:0.5461, val_acc:80.00%
#  Epoch 441: iteration 106/107
# Epoch 441 --> loss:0.2481, acc:91.19%, val_loss:0.5906, val_acc:81.38%
#  Epoch 442: iteration 106/107
# Epoch 442 --> loss:0.2402, acc:91.48%, val_loss:0.3889, val_acc:85.98%
#  Epoch 443: iteration 106/107
# Epoch 443 --> loss:0.2458, acc:90.93%, val_loss:0.3321, val_acc:89.43%
#  Epoch 444: iteration 106/107
# Epoch 444 --> loss:0.2531, acc:90.29%, val_loss:0.2893, val_acc:92.41%
#  Epoch 445: iteration 106/107
# Epoch 445 --> loss:0.2601, acc:90.17%, val_loss:0.2316, val_acc:94.25%
#  Epoch 446: iteration 106/107
# Epoch 446 --> loss:0.2241, acc:91.57%, val_loss:0.3704, val_acc:88.05%
#  Epoch 447: iteration 106/107
# Epoch 447 --> loss:0.2330, acc:91.59%, val_loss:0.4258, val_acc:84.83%
#  Epoch 448: iteration 106/107
# Epoch 448 --> loss:0.2442, acc:90.87%, val_loss:0.2079, val_acc:95.63%
#  Epoch 449: iteration 106/107
# Epoch 449 --> loss:0.2398, acc:91.28%, val_loss:0.2517, val_acc:92.64%
#  Epoch 450: iteration 106/107
# Epoch 450 --> loss:0.2056, acc:92.20%, val_loss:0.2324, val_acc:93.56%
#  Epoch 451: iteration 106/107
# Epoch 451 --> loss:0.2834, acc:89.36%, val_loss:0.3356, val_acc:90.34%
#  Epoch 452: iteration 106/107
# Epoch 452 --> loss:0.2414, acc:90.87%, val_loss:0.2536, val_acc:92.18%
#  Epoch 453: iteration 106/107
# Epoch 453 --> loss:0.2696, acc:89.51%, val_loss:0.2658, val_acc:91.49%
#  Epoch 454: iteration 106/107
# Epoch 454 --> loss:0.2690, acc:90.64%, val_loss:0.3083, val_acc:90.34%
#  Epoch 455: iteration 106/107
# Epoch 455 --> loss:0.2406, acc:90.70%, val_loss:0.3479, val_acc:87.82%
#  Epoch 456: iteration 106/107
# Epoch 456 --> loss:0.2361, acc:91.45%, val_loss:0.1921, val_acc:95.63%
#  Epoch 457: iteration 106/107
# Epoch 457 --> loss:0.2567, acc:90.90%, val_loss:0.3650, val_acc:89.20%
#  Epoch 458: iteration 106/107
# Epoch 458 --> loss:0.2237, acc:91.86%, val_loss:0.3448, val_acc:88.51%
#  Epoch 459: iteration 106/107
# Epoch 459 --> loss:0.2433, acc:90.61%, val_loss:0.2733, val_acc:93.10%
#  Epoch 460: iteration 106/107
# Epoch 460 --> loss:0.2325, acc:91.62%, val_loss:0.3206, val_acc:90.80%
#  Epoch 461: iteration 106/107
# Epoch 461 --> loss:0.2487, acc:90.96%, val_loss:0.4269, val_acc:84.60%
#  Epoch 462: iteration 106/107
# Epoch 462 --> loss:0.2538, acc:90.32%, val_loss:0.2941, val_acc:92.87%
#  Epoch 463: iteration 106/107
# Epoch 463 --> loss:0.2608, acc:90.17%, val_loss:0.3188, val_acc:89.66%
#  Epoch 464: iteration 106/107
# Epoch 464 --> loss:0.2382, acc:91.54%, val_loss:0.2702, val_acc:92.41%
#  Epoch 465: iteration 106/107
# Epoch 465 --> loss:0.2160, acc:92.03%, val_loss:0.7340, val_acc:74.25%
#  Epoch 466: iteration 106/107
# Epoch 466 --> loss:0.2599, acc:90.49%, val_loss:0.3546, val_acc:88.05%
#  Epoch 467: iteration 106/107
# Epoch 467 --> loss:0.2454, acc:91.22%, val_loss:0.2305, val_acc:93.10%
#  Epoch 468: iteration 106/107
# Epoch 468 --> loss:0.2503, acc:90.75%, val_loss:0.4268, val_acc:85.06%
#  Epoch 469: iteration 106/107
# Epoch 469 --> loss:0.2555, acc:90.43%, val_loss:0.2571, val_acc:92.18%
#  Epoch 470: iteration 106/107
# Epoch 470 --> loss:0.2478, acc:90.90%, val_loss:0.3756, val_acc:86.67%
#  Epoch 471: iteration 106/107
# Epoch 471 --> loss:0.2678, acc:89.86%, val_loss:0.1942, val_acc:94.02%
#  Epoch 472: iteration 106/107
# Epoch 472 --> loss:0.2496, acc:90.81%, val_loss:0.2626, val_acc:91.72%
#  Epoch 473: iteration 106/107
# Epoch 473 --> loss:0.2387, acc:90.61%, val_loss:0.3606, val_acc:89.89%
#  Epoch 474: iteration 106/107
# Epoch 474 --> loss:0.2504, acc:90.58%, val_loss:0.2084, val_acc:93.79%
#  Epoch 475: iteration 106/107
# Epoch 475 --> loss:0.2227, acc:92.17%, val_loss:0.2972, val_acc:90.57%
#  Epoch 476: iteration 106/107
# Epoch 476 --> loss:0.2512, acc:90.84%, val_loss:0.3734, val_acc:86.21%
#  Epoch 477: iteration 106/107
# Epoch 477 --> loss:0.2221, acc:91.88%, val_loss:0.2863, val_acc:92.64%
#  Epoch 478: iteration 106/107
# Epoch 478 --> loss:0.2363, acc:91.25%, val_loss:0.2918, val_acc:90.57%
#  Epoch 479: iteration 106/107
# Epoch 479 --> loss:0.2379, acc:91.01%, val_loss:0.3870, val_acc:86.67%
#  Epoch 480: iteration 106/107
# Epoch 480 --> loss:0.2328, acc:91.62%, val_loss:0.2559, val_acc:91.72%
#  Epoch 481: iteration 106/107
# Epoch 481 --> loss:0.2517, acc:90.81%, val_loss:0.3528, val_acc:88.74%
#  Epoch 482: iteration 106/107
# Epoch 482 --> loss:0.2217, acc:91.62%, val_loss:0.3571, val_acc:86.44%
#  Epoch 483: iteration 106/107
# Epoch 483 --> loss:0.2564, acc:90.72%, val_loss:0.4182, val_acc:85.29%
#  Epoch 484: iteration 106/107
# Epoch 484 --> loss:0.2306, acc:91.10%, val_loss:0.3528, val_acc:88.51%
#  Epoch 485: iteration 106/107
# Epoch 485 --> loss:0.2479, acc:90.55%, val_loss:0.3291, val_acc:88.74%
#  Epoch 486: iteration 106/107
# Epoch 486 --> loss:0.2177, acc:91.86%, val_loss:0.3389, val_acc:88.74%
#  Epoch 487: iteration 106/107
# Epoch 487 --> loss:0.2514, acc:90.81%, val_loss:0.2429, val_acc:93.56%
#  Epoch 488: iteration 106/107
# Epoch 488 --> loss:0.2409, acc:90.99%, val_loss:0.5970, val_acc:78.39%
#  Epoch 489: iteration 106/107
# Epoch 489 --> loss:0.2501, acc:90.87%, val_loss:0.2552, val_acc:93.33%
#  Epoch 490: iteration 106/107
# Epoch 490 --> loss:0.2349, acc:91.16%, val_loss:0.4965, val_acc:83.22%
#  Epoch 491: iteration 106/107
# Epoch 491 --> loss:0.2238, acc:92.29%, val_loss:0.4672, val_acc:82.99%
#  Epoch 492: iteration 106/107
# Epoch 492 --> loss:0.2425, acc:91.04%, val_loss:0.4527, val_acc:85.98%
#  Epoch 493: iteration 106/107
# Epoch 493 --> loss:0.2414, acc:90.93%, val_loss:0.3471, val_acc:88.05%
#  Epoch 494: iteration 106/107
# Epoch 494 --> loss:0.2548, acc:90.32%, val_loss:0.3229, val_acc:90.34%
#  Epoch 495: iteration 106/107
# Epoch 495 --> loss:0.2475, acc:90.78%, val_loss:0.2779, val_acc:92.18%
#  Epoch 496: iteration 106/107
# Epoch 496 --> loss:0.2515, acc:90.43%, val_loss:0.3192, val_acc:91.26%
#  Epoch 497: iteration 106/107
# Epoch 497 --> loss:0.2420, acc:91.22%, val_loss:0.3418, val_acc:89.20%
#  Epoch 498: iteration 106/107
# Epoch 498 --> loss:0.2452, acc:90.64%, val_loss:0.3088, val_acc:89.20%
#  Epoch 499: iteration 106/107
# Epoch 499 --> loss:0.2421, acc:91.16%, val_loss:0.2923, val_acc:91.49%

# %% [markdown]
# ### Save model

# %%
path_ = '/content/drive/My Drive/Colab Notebooks/'
SAVE_PATH = os.path.join(path_ ,'models')
os.makedirs('models',exist_ok=True)
torch.save(model.state_dict(),os.path.join(SAVE_PATH,'cnn_lstm_model.pt'))
print('Model is saved to {}'.format(os.path.join(SAVE_PATH,'cnn_lstm_model.pt')))
# Out:
# Model is saved to /content/drive/My Drive/Colab Notebooks/models/cnn_lstm_model.pt

# %% [markdown]
# ### Load model

# %%
LOAD_PATH = os.path.join(path_,'models')
model = HybridModel(len(EMOTIONS))
model.load_state_dict(torch.load(os.path.join(LOAD_PATH,'cnn_lstm_model.pt')))
print('Model is loaded from {}'.format(os.path.join(LOAD_PATH,'cnn_lstm_model.pt')))
# Out:
# Model is loaded from /content/drive/My Drive/Colab Notebooks/models/cnn_lstm_model.pt

# %% [markdown]
# ### Test

# %%
X_test_tensor = torch.tensor(X_test,device=device).float()
Y_test_tensor = torch.tensor(Y_test,dtype=torch.long,device=device)
test_loss, test_acc, predictions = validate(X_test_tensor,Y_test_tensor)
print(f'Test loss is {test_loss:.3f}')
print(f'Test accuracy is {test_acc:.2f}%')
# Out:
# Test loss is 0.333
# Test accuracy is 90.11%

# %%
# test train accuracy
print(acc_lst)
print(val_acc_lst)
plt.plot(acc_lst, label='Train')
plt.plot(val_acc_lst, label='Val')
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend()
plt.savefig(
    f'/content/drive/My Drive/Colab Notebooks/results/test_train_accuracy.pdf')

plt.close()
# Out:
# [tensor(9.3750, device='cuda:0'), tensor(15.6250, device='cuda:0'), tensor(25., device='cuda:0'), tensor(25., device='cuda:0'), tensor(25., device='cuda:0'), tensor(28.1250, device='cuda:0'), tensor(15.6250, device='cuda:0'), tensor(43.7500, device='cuda:0'), tensor(40.6250, device='cuda:0'), tensor(43.7500, device='cuda:0'), tensor(25., device='cuda:0'), tensor(34.3750, device='cuda:0'), tensor(31.2500, device='cuda:0'), tensor(37.5000, device='cuda:0'), tensor(43.7500, device='cuda:0'), tensor(25., device='cuda:0'), tensor(34.3750, device='cuda:0'), tensor(37.5000, device='cuda:0'), tensor(31.2500, device='cuda:0'), tensor(21.8750, device='cuda:0'), tensor(50., device='cuda:0'), tensor(50., device='cuda:0'), tensor(34.3750, device='cuda:0'), tensor(25., device='cuda:0'), tensor(37.5000, device='cuda:0'), tensor(46.8750, device='cuda:0'), tensor(40.6250, device='cuda:0'), tensor(46.8750, device='cuda:0'), tensor(34.3750, device='cuda:0'), tensor(50., device='cuda:0'), tensor(43.7500, device='cuda:0'), tensor(43.7500, device='cuda:0'), tensor(40.6250, device='cuda:0'), tensor(50., device='cuda:0'), tensor(59.3750, device='cuda:0'), tensor(46.8750, device='cuda:0'), tensor(40.6250, device='cuda:0'), tensor(37.5000, device='cuda:0'), tensor(46.8750, device='cuda:0'), tensor(50., device='cuda:0'), tensor(56.2500, device='cuda:0'), tensor(46.8750, device='cuda:0'), tensor(53.1250, device='cuda:0'), tensor(53.1250, device='cuda:0'), tensor(53.1250, device='cuda:0'), tensor(56.2500, device='cuda:0'), tensor(50., device='cuda:0'), tensor(43.7500, device='cuda:0'), tensor(56.2500, device='cuda:0'), tensor(59.3750, device='cuda:0'), tensor(56.2500, device='cuda:0'), tensor(53.1250, device='cuda:0'), tensor(43.7500, device='cuda:0'), tensor(65.6250, device='cuda:0'), tensor(75., device='cuda:0'), tensor(56.2500, device='cuda:0'), tensor(59.3750, device='cuda:0'), tensor(50., device='cuda:0'), tensor(50., device='cuda:0'), tensor(50., device='cuda:0'), tensor(50., device='cuda:0'), tensor(50., device='cuda:0'), tensor(62.5000, device='cuda:0'), tensor(59.3750, device='cuda:0'), tensor(59.3750, device='cuda:0'), tensor(53.1250, device='cuda:0'), tensor(56.2500, device='cuda:0'), tensor(62.5000, device='cuda:0'), tensor(78.1250, device='cuda:0'), tensor(71.8750, device='cuda:0'), tensor(59.3750, device='cuda:0'), tensor(56.2500, device='cuda:0'), tensor(65.6250, device='cuda:0'), tensor(75., device='cuda:0'), tensor(56.2500, device='cuda:0'), tensor(53.1250, device='cuda:0'), tensor(62.5000, device='cuda:0'), tensor(59.3750, device='cuda:0'), tensor(62.5000, device='cuda:0'), tensor(62.5000, device='cuda:0'), tensor(71.8750, device='cuda:0'), tensor(50., device='cuda:0'), tensor(59.3750, device='cuda:0'), tensor(62.5000, device='cuda:0'), tensor(65.6250, device='cuda:0'), tensor(68.7500, device='cuda:0'), tensor(87.5000, device='cuda:0'), tensor(68.7500, device='cuda:0'), tensor(71.8750, device='cuda:0'), tensor(78.1250, device='cuda:0'), tensor(81.2500, device='cuda:0'), tensor(78.1250, device='cuda:0'), tensor(62.5000, device='cuda:0'), tensor(59.3750, device='cuda:0'), tensor(84.3750, device='cuda:0'), tensor(84.3750, device='cuda:0'), tensor(78.1250, device='cuda:0'), tensor(75., device='cuda:0'), tensor(81.2500, device='cuda:0'), tensor(71.8750, device='cuda:0'), tensor(62.5000, device='cuda:0'), tensor(81.2500, device='cuda:0'), tensor(71.8750, device='cuda:0'), tensor(75., device='cuda:0'), tensor(87.5000, device='cuda:0'), tensor(65.6250, device='cuda:0'), tensor(75., device='cuda:0'), tensor(71.8750, device='cuda:0'), tensor(84.3750, device='cuda:0'), tensor(75., device='cuda:0'), tensor(71.8750, device='cuda:0'), tensor(75., device='cuda:0'), tensor(71.8750, device='cuda:0'), tensor(75., device='cuda:0'), tensor(84.3750, device='cuda:0'), tensor(81.2500, device='cuda:0'), tensor(84.3750, device='cuda:0'), tensor(84.3750, device='cuda:0'), tensor(75., device='cuda:0'), tensor(87.5000, device='cuda:0'), tensor(87.5000, device='cuda ...
# [tensor(13.3333, device='cuda:0'), tensor(14.9425, device='cuda:0'), tensor(13.7931, device='cuda:0'), tensor(13.5632, device='cuda:0'), tensor(13.7931, device='cuda:0'), tensor(13.1034, device='cuda:0'), tensor(14.9425, device='cuda:0'), tensor(18.1609, device='cuda:0'), tensor(24.8276, device='cuda:0'), tensor(29.1954, device='cuda:0'), tensor(30.1149, device='cuda:0'), tensor(30.1149, device='cuda:0'), tensor(30.5747, device='cuda:0'), tensor(29.4253, device='cuda:0'), tensor(30.8046, device='cuda:0'), tensor(27.1264, device='cuda:0'), tensor(32.1839, device='cuda:0'), tensor(32.4138, device='cuda:0'), tensor(32.1839, device='cuda:0'), tensor(34.2529, device='cuda:0'), tensor(32.4138, device='cuda:0'), tensor(35.8621, device='cuda:0'), tensor(38.6207, device='cuda:0'), tensor(36.5517, device='cuda:0'), tensor(33.7931, device='cuda:0'), tensor(36.5517, device='cuda:0'), tensor(39.5402, device='cuda:0'), tensor(35.6322, device='cuda:0'), tensor(42.0690, device='cuda:0'), tensor(40.4598, device='cuda:0'), tensor(37.2414, device='cuda:0'), tensor(44.3678, device='cuda:0'), tensor(40., device='cuda:0'), tensor(40., device='cuda:0'), tensor(44.3678, device='cuda:0'), tensor(46.4368, device='cuda:0'), tensor(45.2874, device='cuda:0'), tensor(47.3563, device='cuda:0'), tensor(46.8966, device='cuda:0'), tensor(44.5977, device='cuda:0'), tensor(52.8736, device='cuda:0'), tensor(53.7931, device='cuda:0'), tensor(47.1264, device='cuda:0'), tensor(40., device='cuda:0'), tensor(52.8736, device='cuda:0'), tensor(58.6207, device='cuda:0'), tensor(57.2414, device='cuda:0'), tensor(57.7011, device='cuda:0'), tensor(55.4023, device='cuda:0'), tensor(55.8621, device='cuda:0'), tensor(57.0115, device='cuda:0'), tensor(61.1494, device='cuda:0'), tensor(40.2299, device='cuda:0'), tensor(56.5517, device='cuda:0'), tensor(47.1264, device='cuda:0'), tensor(55.1724, device='cuda:0'), tensor(50.8046, device='cuda:0'), tensor(61.6092, device='cuda:0'), tensor(52.6437, device='cuda:0'), tensor(51.9540, device='cuda:0'), tensor(60.9195, device='cuda:0'), tensor(54.7126, device='cuda:0'), tensor(61.8391, device='cuda:0'), tensor(66.4368, device='cuda:0'), tensor(60.2299, device='cuda:0'), tensor(64.8276, device='cuda:0'), tensor(65.5172, device='cuda:0'), tensor(65.2874, device='cuda:0'), tensor(63.2184, device='cuda:0'), tensor(59.7701, device='cuda:0'), tensor(67.5862, device='cuda:0'), tensor(61.8391, device='cuda:0'), tensor(50.5747, device='cuda:0'), tensor(64.3678, device='cuda:0'), tensor(63.9080, device='cuda:0'), tensor(63.6782, device='cuda:0'), tensor(68.0460, device='cuda:0'), tensor(65.7471, device='cuda:0'), tensor(70.8046, device='cuda:0'), tensor(67.5862, device='cuda:0'), tensor(57.0115, device='cuda:0'), tensor(67.3563, device='cuda:0'), tensor(69.1954, device='cuda:0'), tensor(63.9080, device='cuda:0'), tensor(71.2644, device='cuda:0'), tensor(62.2989, device='cuda:0'), tensor(71.9540, device='cuda:0'), tensor(66.2069, device='cuda:0'), tensor(59.7701, device='cuda:0'), tensor(62.5287, device='cuda:0'), tensor(62.9885, device='cuda:0'), tensor(62.5287, device='cuda:0'), tensor(68.7356, device='cuda:0'), tensor(69.6552, device='cuda:0'), tensor(72.1839, device='cuda:0'), tensor(68.7356, device='cuda:0'), tensor(60.4598, device='cuda:0'), tensor(65.0575, device='cuda:0'), tensor(64.8276, device='cuda:0'), tensor(62.2989, device='cuda:0'), tensor(71.7241, device='cuda:0'), tensor(62.9885, device='cuda:0'), tensor(65.9770, device='cuda:0'), tensor(69.1954, device='cuda:0'), tensor(72.8736, device='cuda:0'), tensor(78.6207, device='cuda:0'), tensor(79.5402, device='cuda:0'), tensor(70.8046, device='cuda:0'), tensor(72.4138, device='cuda:0'), tensor(67.3563, device='cuda:0'), tensor(69.8851, device='cuda:0'), tensor(66.2069, device='cuda:0'), tensor(66.4368, device='cuda:0'), tensor(63.6782, device='cuda:0'), tensor(73.3333, device='cuda:0'), tensor(70.1149, device='cuda:0'), tensor(75.4023, device='cuda:0'), tensor(71.0345, device='cuda:0'), ...

# %%
# confusion matrix
from sklearn.metrics import confusion_matrix
import seaborn as sn

predictions = predictions.tolist()
cm = confusion_matrix(Y_test, predictions)
names = [EMOTIONS[ind] for ind in range(len(EMOTIONS))]
df_cm = pd.DataFrame(cm, index=names, columns=names)
# plt.figure(figsize=(10,7))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}) # font size
plt.savefig(
    f'/content/drive/My Drive/Colab Notebooks/results/confusion_matrix.png')
plt.show()

# %%
# correlation between emotion intensity and prediction
correct_strong = 0
correct_normal = 0
wrong_strong = 0
wrong_normal = 0
for i in range(len(X_test)):
    intensity = data_df.loc[test_ind[i],'Intensity']
    if Y_test[i] == predictions[i]: # correct prediction
        if  intensity == 'normal':
            correct_normal += 1
        else:
            correct_strong += 1
    else: # wrong prediction
        if intensity == 'normal':
            wrong_normal += 1
        else:
            wrong_strong += 1
array = np.array([[wrong_normal,wrong_strong],[correct_normal,correct_strong]])
df = pd.DataFrame(array,['wrong','correct'],['normal','strong'])
sn.set(font_scale=1.4) # for label size
sn.heatmap(df, annot=True, annot_kws={"size": 16}) # font size
plt.savefig(
    f'/content/drive/My Drive/Colab Notebooks/results/correlation_Intensity_correctness.png')
plt.show()

# %%
# correlation between gender and corectness
correct_male = 0
correct_female = 0
wrong_male = 0
wrong_female = 0
for i in range(len(X_test)):
    gender = data_df.loc[test_ind[i],'Gender']
    if Y_test[i] == predictions[i]: # correct prediction
        if  gender == 'male':
            correct_male += 1
        else:
            correct_female += 1
    else: # wrong prediction
        if gender == 'male':
            wrong_male += 1
        else:
            wrong_female += 1
array = np.array([[wrong_male,wrong_female],[correct_male,correct_female]])
df = pd.DataFrame(array,['wrong','correct'],['male','female'])
sn.set(font_scale=1.4) # for label size
sn.heatmap(df, annot=True, annot_kws={"size": 16}) # font size
plt.savefig(
    f'/content/drive/My Drive/Colab Notebooks/results/correlation_gender_correctness.png')
plt.show()

# %% [markdown]
# ### Plot Loss

# %%
plt.plot(losses,'b')
plt.plot(val_losses,'r')
plt.legend(['train loss','val loss'])
plt.savefig(
    f'/content/drive/My Drive/Colab Notebooks/results/train_test_loss.pdf')
